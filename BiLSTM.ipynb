# %%
import torch
import torch.nn as nn
from torch.functional import F
from sklearn import metrics
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
# %matplotlib inline
import numpy as np
from utils import plot_confusion_matrix

# %%
x_train = torch.load("dataset/x_train")
y_train = torch.load("dataset/y_train")
x_test = torch.load("dataset/x_test")
y_test = torch.load("dataset/y_test")

# %%
class BiRNN(nn.Module):
    def __init__(self, embed_size, num_hiddens, num_layers, classes):
        super(BiRNN, self).__init__()
        # bidirectional设为True即得到双向循环神经网络

        self.encoder = nn.LSTM(input_size=embed_size,
                               hidden_size=num_hiddens,
                               num_layers=num_layers,
                               bidirectional=True)
        
        # 初始时间步和最终时间步的隐藏状态作为全连接层输入
        self.classifier = nn.Sequential(
            nn.Linear(4*num_hiddens, 128*num_hiddens),
            nn.BatchNorm1d(128*num_hiddens),
            nn.Sigmoid(),
            nn.Linear(128*num_hiddens,classes)
        )


    def forward(self, inputs):
        # inputs的形状是(批量大小, 词数, 词向量维度)，因为LSTM需要将序列长度(seq_len)作为第一维，所以将输入转置后
        # 再提取词特征，输出形状为(词数, 批量大小, 词向量维度)
        inputs = torch.transpose(inputs, 0, 1)
        # outputs形状是(词数, 批量大小, 2 * 隐藏单元个数)
        outputs, _ = self.encoder(inputs)  # output, (h, c)
        # 连结初始时间步和最终时间步的隐藏状态作为全连接层输入。它的形状为 (批量大小, 4 * 隐藏单元个数)。
        outs = torch.cat((outputs[0], outputs[-1]), -1)
        outs = self.classifier(outs)
        return outs

# %%
model = BiRNN(embed_size=100, num_hiddens=100, num_layers=5, classes=5)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
def batch_padding(batch_data):
    # 针对一批句子的长度（词向量个数）不一样时，全部补0到最大句子长度
    new_batch_data = []
    max_len = 0
    for s in batch_data:
        s = torch.tensor(s)
        new_batch_data.append(s)
        max_len = max(max_len,s.shape[0])
    for i in range(len(new_batch_data)):
        new_batch_data[i] = F.pad(new_batch_data[i], [0, 0, 0, max_len-new_batch_data[i].shape[0]])
    return torch.stack(new_batch_data, 0)

# %%
sentences = batch_padding(x_train[0:5])
sentences.shape # [batch_size,句子中词的个数,词向量维度]
# Out:
# torch.Size([5, 7, 100])

# %%
print(model(sentences.to(device))) # 输出为OneHot编码形式
# Out:
# tensor([[-0.4815,  0.0205,  0.0838,  0.1002,  0.0515],
#         [-0.4756,  0.0108,  0.0760,  0.1104,  0.0473],
#         [-0.4810,  0.0013,  0.0999,  0.0968,  0.0534],
#         [-0.4521,  0.0031,  0.0888,  0.0920,  0.0349],
#         [-0.4560,  0.0114,  0.1024,  0.0974,  0.0354]], device='cuda:0',
#        grad_fn=<AddmmBackward>)

# %% [markdown]
# ## 训练

# %%
def train(model,dataset_x,dataset_y,num_epochs,
batch_size,optimizer,loss,batch_loss_list,batch_acc_list):
    model.train()
    for epoch in range(num_epochs):
        print("epoch",epoch)
        train_l_sum, train_acc_sum, n = 0.0, 0.0, 0
        batch_num = len(dataset_x) // batch_size
        for i in range(batch_num):
            X = batch_padding(dataset_x[i*batch_size : (i+1)*batch_size]).to(device)
            y = torch.tensor(dataset_y[i*batch_size : (i+1)*batch_size]).to(device)
            y_hat = model(X)
            y = y.argmax(dim=1).long()
            loss_ = loss(y_hat, y)
            optimizer.zero_grad()
            loss_.backward()
            optimizer.step()

            batch_loss = loss_.cpu().item()
            batch_acc = (y_hat.argmax(dim=1) == y).sum().cpu().item()
            batch_loss_list.append(batch_loss/batch_size)
            batch_acc_list.append(batch_acc/batch_size)
            print(f"epoch:{epoch},batch loss:{batch_loss/batch_size},batch acc:{batch_acc/batch_size}")

# %%
lr = 0.001
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad,model.parameters()), lr=lr)
loss = nn.CrossEntropyLoss().to(device)

# %%
batch_loss_list = []
batch_acc_list = []

# %%
print("training... ")
train(model=model,dataset_x=x_train,dataset_y=y_train,
num_epochs=30,batch_size=256,optimizer=optimizer,loss=loss,
batch_loss_list=batch_loss_list,batch_acc_list=batch_acc_list)
torch.save(model,"models/BiLSTM_v3.npy")
# Out:
# training...
# epoch 0
# epoch:0,batch loss:0.006268870085477829,batch acc:0.140625
# epoch:0,batch loss:0.020285077393054962,batch acc:0.45703125
# epoch:0,batch loss:0.021796951070427895,batch acc:0.390625
# epoch:0,batch loss:0.005958252586424351,batch acc:0.5078125
# epoch:0,batch loss:0.016148123890161514,batch acc:0.2734375
# epoch:0,batch loss:0.020752713084220886,batch acc:0.21875
# epoch:0,batch loss:0.018959980458021164,batch acc:0.296875
# epoch:0,batch loss:0.015105965547263622,batch acc:0.2109375
# epoch:0,batch loss:0.008369247429072857,batch acc:0.203125
# epoch:0,batch loss:0.009736208245158195,batch acc:0.42578125
# epoch:0,batch loss:0.012235795147716999,batch acc:0.4296875
# epoch:0,batch loss:0.012902962975203991,batch acc:0.41796875
# epoch:0,batch loss:0.013190438970923424,batch acc:0.203125
# epoch:0,batch loss:0.009554258547723293,batch acc:0.2734375
# epoch:0,batch loss:0.006935362704098225,batch acc:0.421875
# epoch:0,batch loss:0.009750016033649445,batch acc:0.20703125
# epoch:0,batch loss:0.010830523446202278,batch acc:0.234375
# epoch:0,batch loss:0.006122812163084745,batch acc:0.3828125
# epoch:0,batch loss:0.008668497204780579,batch acc:0.37109375
# epoch:0,batch loss:0.010198822245001793,batch acc:0.28125
# epoch:0,batch loss:0.006907700095325708,batch acc:0.4453125
# epoch:0,batch loss:0.006301377899944782,batch acc:0.46875
# epoch:0,batch loss:0.00618286756798625,batch acc:0.35546875
# epoch:0,batch loss:0.008605554699897766,batch acc:0.3359375
# epoch:0,batch loss:0.007356963586062193,batch acc:0.3515625
# epoch:0,batch loss:0.007389524485915899,batch acc:0.48828125
# epoch:0,batch loss:0.006106875371187925,batch acc:0.51953125
# epoch:0,batch loss:0.008276453241705894,batch acc:0.4765625
# epoch:0,batch loss:0.006775303278118372,batch acc:0.453125
# epoch:0,batch loss:0.005434215068817139,batch acc:0.4453125
# epoch:0,batch loss:0.0074270921759307384,batch acc:0.26953125
# epoch:0,batch loss:0.007939931005239487,batch acc:0.26171875
# epoch:0,batch loss:0.005926297977566719,batch acc:0.34375
# epoch:0,batch loss:0.004529494792222977,batch acc:0.48828125
# epoch:0,batch loss:0.007439424283802509,batch acc:0.44140625
# epoch:0,batch loss:0.006723883096128702,batch acc:0.49609375
# epoch:0,batch loss:0.007351103704422712,batch acc:0.44921875
# epoch:0,batch loss:0.006032008212059736,batch acc:0.44140625
# epoch:0,batch loss:0.004719599150121212,batch acc:0.54296875
# epoch:0,batch loss:0.006083214655518532,batch acc:0.35546875
# epoch:0,batch loss:0.006053858436644077,batch acc:0.36328125
# epoch:0,batch loss:0.00458505330607295,batch acc:0.5625
# epoch:0,batch loss:0.006592074409127235,batch acc:0.42578125
# epoch:0,batch loss:0.006385852117091417,batch acc:0.38671875
# epoch:0,batch loss:0.005492269527167082,batch acc:0.46484375
# epoch:0,batch loss:0.006483715958893299,batch acc:0.31640625
# epoch:0,batch loss:0.005478396080434322,batch acc:0.4140625
# epoch:0,batch loss:0.00591739546507597,batch acc:0.40625
# epoch:0,batch loss:0.00662800669670105,batch acc:0.43359375
# epoch:0,batch loss:0.004896385129541159,batch acc:0.51953125
# epoch:0,batch loss:0.005764099769294262,batch acc:0.50390625
# epoch:0,batch loss:0.00571885472163558,batch acc:0.484375
# epoch:0,batch loss:0.005224952474236488,batch acc:0.4453125
# epoch:0,batch loss:0.00593224773183465,batch acc:0.39453125
# epoch:0,batch loss:0.004974121227860451,batch acc:0.49609375
# epoch:0,batch loss:0.005002861842513084,batch acc:0.48828125
# epoch:0,batch loss:0.004972607828676701,batch acc:0.5078125
# epoch:0,batch loss:0.005282025784254074,batch acc:0.46875
# epoch:0,batch loss:0.005552905611693859,batch acc:0.453125
# epoch:0,batch loss:0.006824472453445196,batch acc:0.328125
# epoch:0,batch loss:0.0052754380740225315,batch acc:0.5234375
# epoch:0,batch loss:0.005196575075387955,batch acc:0.4296875
# epoch:0,batch loss:0.004663518629968166,batch acc:0.57421875
# epoch:0,batch loss:0.005673895590007305,batch acc:0.41796875
# epoch:0,batch loss:0.007050337269902229,batch acc:0.38671875
# epoch:0,batch loss:0.0054391054436564445,batch acc:0.3828125
# epoch:0,batch loss:0.005295251030474901,batch acc:0.44921875
# epoch:0,batch loss:0.005499876569956541,batch acc:0.4140625
# epoch:0,batch loss:0.004830500110983849,batch acc:0.44140625
# epoch:0,batch loss:0.004351165145635605,batch acc:0.5859375
# epoch:0,batch loss:0.005641051568090916,batch acc:0.50390625
# epoch:0,batch loss:0.005081981886178255,batch acc:0.5390625
# epoch:0,batch loss:0.005362881813198328,batch acc:0.40625
# epoch:0,batch loss:0.0057633500546216965,batch acc:0.36328125
# epoch:0,batch loss:0.0058550117537379265,batch acc:0.34375
# epoch:0,batch loss:0.005255585070699453,batch acc:0.48046875
# epoch:0,batch loss:0.005480551160871983,batch acc:0.4375
# epoch:0,batch loss:0.005977079272270203,batch acc:0.421875
# epoch:0,batch loss:0.005683026742190123,batch acc:0.42578125
# epoch:0,batch loss:0.005080011673271656,batch acc:0.453125
# epoch:0,batch loss:0.004074102733284235,batch acc:0.58984375
# epoch:0,batch loss:0.006573840510100126,batch acc:0.4609375
# epoch:0,batch loss:0.005298817530274391,batch acc:0.53515625
# epoch:0,batch loss:0.006355531048029661,batch acc:0.4765625
# epoch:0,batch loss:0.004643462598323822,batch acc:0.4921875
# epoch:0,batch loss:0.00520284753292799,batch acc:0.4609375
# epoch:0,batch loss:0.0054496233351528645,batch acc:0.40625
# epoch:0,batch loss:0.004871214274317026,batch acc:0.52734375
# epoch:0,batch loss:0.004318705759942532,batch acc:0.56640625
# epoch:0,batch loss:0.005456241779029369,batch acc:0.3828125
# epoch:0,batch loss:0.005644179414957762,batch acc:0.421875
# epoch:0,batch loss:0.006019096355885267,batch acc:0.35546875
# epoch:0,batch loss:0.005523528903722763,batch acc:0.46875
# epoch:0,batch loss:0.004472522996366024,batch acc:0.5703125
# epoch:0,batch loss:0.0055615841411054134,batch acc:0.46484375
# epoch:0,batch loss:0.005445738323032856,batch acc:0.49609375
# epoch:0,batch loss:0.0049989353865385056,batch acc:0.48046875
# epoch:0,batch loss:0.005227628163993359,batch acc:0.453125
# epoch:0,batch loss:0.004331649746745825,batch acc:0.578125
# epoch:0,batch loss:0.004938096273690462,batch acc:0.43359375
# epoch:0,batch loss:0.006019594147801399,batch acc:0.47265625
# epoch:0,batch loss:0.005697783548384905,batch acc:0.48046875
# epoch:0,batch loss:0.005261954851448536,batch acc:0.5078125
# epoch:0,batch loss:0.004524590913206339,batch acc:0.60546875
# epoch:0,batch loss:0.005455567501485348,batch acc:0.46484375
# epoch:0,batch loss:0.004435824695974588,batch acc:0.6484375
# epoch:0,batch loss:0.00492570037022233,batch acc:0.45703125
# epoch:0,batch loss:0.005058938637375832,batch acc:0.54296875
# epoch:0,batch loss:0.004423256032168865,batch acc:0.56640625
# epoch:0,batch loss:0.005334860645234585,batch acc:0.453125
# epoch:0,batch loss:0.004286909010261297,batch acc:0.546875
# epoch:0,batch loss:0.005029947962611914,batch acc:0.5078125
# epoch:0,batch loss:0.004271151963621378,batch acc:0.55078125
# epoch:0,batch loss:0.004660027101635933,batch acc:0.46875
# epoch:0,batch loss:0.0055079590529203415,batch acc:0.515625
# epoch:0,batch loss:0.004856478422880173,batch acc:0.51953125
# epoch:0,batch loss:0.005372865125536919,batch acc:0.39453125
# epoch:0,batch loss:0.004552698228508234,batch acc:0.546875
# epoch:0,batch loss:0.00530792074277997,batch acc:0.515625
# epoch:0,batch loss:0.0046108802780508995,batch acc:0.5703125
# epoch:0,batch loss:0.005055944435298443,batch acc:0.4609375
# epoch:0,batch loss:0.004798217676579952,batch acc:0.4921875
# epoch:0,batch loss:0.005682296119630337,batch acc:0.39453125
# epoch:0,batch loss:0.005227463319897652,batch acc:0.47265625
# epoch:0,batch loss:0.005761189851909876,batch acc:0.4375
# epoch:0,batch loss:0.005859803408384323,batch acc:0.4765625
# epoch:0,batch loss:0.00553100137040019,batch acc:0.4140625
# epoch:0,batch loss:0.004862254951149225,batch acc:0.5078125
# epoch:0,batch loss:0.005135727114975452,batch acc:0.51953125
# epoch:0,batch loss:0.0065035284496843815,batch acc:0.46484375
# epoch:0,batch loss:0.005755327176302671,batch acc:0.51171875
# epoch:0,batch loss:0.004426526837050915,batch acc:0.59765625
# epoch:0,batch loss:0.006288561504334211,batch acc:0.33203125
# epoch:0,batch loss:0.005063010845333338,batch acc:0.4921875
# epoch:0,batch loss:0.005380883347243071,batch acc:0.46875
# epoch:0,batch loss:0.005489070434123278,batch acc:0.5078125
# epoch:0,batch loss:0.005336033180356026,batch acc:0.47265625
# epoch:0,batch loss:0.004246974363923073,batch acc:0.53125
# epoch:0,batch loss:0.005680458154529333,batch acc:0.44140625
# epoch:0,batch loss:0.005165756214410067,batch acc:0.453125
# epoch:0,batch loss:0.005170753225684166,batch acc:0.55078125
# epoch:0,batch loss:0.006461162120103836,batch acc:0.578125
# epoch:0,batch loss:0.0052403053268790245,batch acc:0.55859375
# epoch:0,batch loss:0.006348378490656614,batch acc:0.36328125
# epoch:0,batch loss:0.003993627615272999,batch acc:0.55078125
# epoch:0,batch loss:0.004707209300249815,batch acc:0.51953125
# epoch:0,batch loss:0.005053277127444744,batch acc:0.5
# epoch:0,batch loss:0.005730207543820143,batch acc:0.5234375
# epoch:0,batch loss:0.0052200304344296455,batch acc:0.5625
# epoch:0,batch loss:0.005976490210741758,batch acc:0.44921875
# epoch:0,batch loss:0.004989786073565483,batch acc:0.4921875
# epoch:0,batch loss:0.0059175873175263405,batch acc:0.359375
# epoch:0,batch loss:0.005915632471442223,batch acc:0.4296875
# epoch:0,batch loss:0.005394975189119577,batch acc:0.4921875
# epoch:0,batch loss:0.006767114624381065,batch acc:0.421875
# epoch:0,batch loss:0.004806259647011757,batch acc:0.45703125
# epoch:0,batch loss:0.0043097068555653095,batch acc:0.5234375
# epoch:0,batch loss:0.005472537595778704,batch acc:0.39453125
# epoch:0,batch loss:0.005388555582612753,batch acc:0.4765625
# epoch:0,batch loss:0.005329474341124296,batch acc:0.4765625
# epoch:0,batch loss:0.004907077178359032,batch acc:0.453125
# epoch:0,batch loss:0.004767177160829306,batch acc:0.5078125
# epoch:0,batch loss:0.0053636678494513035,batch acc:0.48046875
# epoch:0,batch loss:0.004746297840029001,batch acc:0.55078125
# epoch:0,batch loss:0.004710928536951542,batch acc:0.54296875
# epoch:0,batch loss:0.0045014373026788235,batch acc:0.51171875
# epoch:0,batch loss:0.004962208215147257,batch acc:0.5
# epoch:0,batch loss:0.004882786422967911,batch acc:0.46484375
# epoch:0,batch loss:0.005349382292479277,batch acc:0.4375
# epoch:0,batch loss:0.0050054192543029785,batch acc:0.5234375
# epoch:0,batch loss:0.005311341490596533,batch acc:0.53125
# epoch:0,batch loss:0.0036347766872495413,batch acc:0.625
# epoch:0,batch loss:0.006424994207918644,batch acc:0.46484375
# epoch:0,batch loss:0.006192030850797892,batch acc:0.5078125
# epoch:0,batch loss:0.006585483439266682,batch acc:0.453125
# epoch:0,batch loss:0.0051554664969444275,batch acc:0.52734375
# epoch:0,batch loss:0.006198966410011053,batch acc:0.35546875
# epoch:0,batch loss:0.0062297252006828785,batch acc:0.421875
# epoch:0,batch loss:0.006174001377075911,batch acc:0.50390625
# epoch:0,batch loss:0.004883503075689077,batch acc:0.55078125
# epoch:0,batch loss:0.0051396554335951805,batch acc:0.4296875
# epoch:0,batch loss:0.00659848703071475,batch acc:0.3671875
# epoch:0,batch loss:0.005408206954598427,batch acc:0.52734375
# epoch:0,batch loss:0.005209696479141712,batch acc:0.51171875
# epoch:0,batch loss:0.005216095130890608,batch acc:0.6328125
# epoch:0,batch loss:0.005944754462689161,batch acc:0.46875
# epoch:0,batch loss:0.006070415023714304,batch acc:0.44140625
# epoch:0,batch loss:0.0054732128046453,batch acc:0.44921875
# epoch:0,batch loss:0.0056877098977565765,batch acc:0.3515625
# epoch:0,batch loss:0.005578166805207729,batch acc:0.40234375
# epoch:0,batch loss:0.005108668934553862,batch acc:0.51953125
# epoch:0,batch loss:0.005486244801431894,batch acc:0.52734375
# epoch:0,batch loss:0.004871838726103306,batch acc:0.53515625
# epoch:0,batch loss:0.005658817011862993,batch acc:0.46484375
# epoch:0,batch loss:0.004981018602848053,batch acc:0.5625
# epoch:0,batch loss:0.004872546531260014,batch acc:0.52734375
# epoch:0,batch loss:0.005841192789375782,batch acc:0.40234375
# epoch:0,batch loss:0.005352627485990524,batch acc:0.4765625
# epoch:0,batch loss:0.0054734377190470695,batch acc:0.46875
# epoch:0,batch loss:0.006218533962965012,batch acc:0.41015625
# epoch:0,batch loss:0.005270082503557205,batch acc:0.5234375
# epoch:0,batch loss:0.005122349131852388,batch acc:0.46875
# epoch:0,batch loss:0.005133789498358965,batch acc:0.5
# epoch:0,batch loss:0.005618647672235966,batch acc:0.41796875
# epoch:0,batch loss:0.0059012435376644135,batch acc:0.55078125
# epoch:0,batch loss:0.005559843499213457,batch acc:0.515625
# epoch:0,batch loss:0.004642275627702475,batch acc:0.57421875
# epoch:0,batch loss:0.004845414776355028,batch acc:0.55078125
# epoch:0,batch loss:0.005129274912178516,batch acc:0.44921875
# epoch:0,batch loss:0.005318661220371723,batch acc:0.4765625
# epoch:0,batch loss:0.005199342034757137,batch acc:0.46875
# epoch:0,batch loss:0.004537561442703009,batch acc:0.62890625
# epoch:0,batch loss:0.00515467906370759,batch acc:0.5390625
# epoch:0,batch loss:0.0063201491720974445,batch acc:0.44921875
# epoch:0,batch loss:0.005212381016463041,batch acc:0.51171875
# epoch:0,batch loss:0.00576289277523756,batch acc:0.46484375
# epoch:0,batch loss:0.0047573368065059185,batch acc:0.45703125
# epoch:0,batch loss:0.0045492700301110744,batch acc:0.5
# epoch:0,batch loss:0.0059896670281887054,batch acc:0.4140625
# epoch:0,batch loss:0.004863742273300886,batch acc:0.52734375
# epoch:0,batch loss:0.004249467980116606,batch acc:0.59765625
# epoch:0,batch loss:0.004501989111304283,batch acc:0.53515625
# epoch:0,batch loss:0.00572455208748579,batch acc:0.41796875
# epoch:0,batch loss:0.005966888274997473,batch acc:0.39453125
# epoch:0,batch loss:0.004921311512589455,batch acc:0.43359375
# epoch:0,batch loss:0.00484657846391201,batch acc:0.546875
# epoch:0,batch loss:0.0041469004936516285,batch acc:0.6328125
# epoch:0,batch loss:0.005192231852561235,batch acc:0.48828125
# epoch:0,batch loss:0.005519595928490162,batch acc:0.50390625
# epoch:0,batch loss:0.005084608681499958,batch acc:0.359375
# epoch:0,batch loss:0.005338943097740412,batch acc:0.44140625
# epoch:0,batch loss:0.004198105540126562,batch acc:0.5625
# epoch:0,batch loss:0.0053001283667981625,batch acc:0.55859375
# epoch:0,batch loss:0.0046967812813818455,batch acc:0.54296875
# epoch:0,batch loss:0.005316995084285736,batch acc:0.4453125
# epoch:0,batch loss:0.005033139139413834,batch acc:0.4765625
# epoch:0,batch loss:0.004887459333986044,batch acc:0.48828125
# epoch:0,batch loss:0.004642777144908905,batch acc:0.53125
# epoch:0,batch loss:0.004604133311659098,batch acc:0.50390625
# epoch:0,batch loss:0.0049199978820979595,batch acc:0.4609375
# epoch:0,batch loss:0.005250794347375631,batch acc:0.4375
# epoch:0,batch loss:0.004487303085625172,batch acc:0.53515625
# epoch:0,batch loss:0.006475625094026327,batch acc:0.36328125
# epoch:0,batch loss:0.0068064345978200436,batch acc:0.3515625
# epoch:0,batch loss:0.005018332507461309,batch acc:0.45703125
# epoch:0,batch loss:0.004577002953737974,batch acc:0.5390625
# epoch:0,batch loss:0.005601563956588507,batch acc:0.5
# epoch:0,batch loss:0.005959105212241411,batch acc:0.47265625
# epoch:0,batch loss:0.004888596944510937,batch acc:0.48046875
# epoch:0,batch loss:0.005296944174915552,batch acc:0.390625
# epoch:0,batch loss:0.005256550386548042,batch acc:0.453125
# epoch:0,batch loss:0.004354730248451233,batch acc:0.57421875
# epoch:0,batch loss:0.004278827924281359,batch acc:0.57421875
# epoch:0,batch loss:0.005198694299906492,batch acc:0.51953125
# epoch:0,batch loss:0.004499414935708046,batch acc:0.515625
# epoch:0,batch loss:0.004604261834174395,batch acc:0.58203125
# epoch:0,batch loss:0.005316694732755423,batch acc:0.50390625
# epoch:0,batch loss:0.004336895886808634,batch acc:0.5625
# epoch:0,batch loss:0.0046157026663422585,batch acc:0.578125
# epoch:0,batch loss:0.0054169707000255585,batch acc:0.4921875
# epoch:0,batch loss:0.005223865620791912,batch acc:0.484375
# epoch:0,batch loss:0.004639801103621721,batch acc:0.5078125
# epoch:0,batch loss:0.005193987395614386,batch acc:0.3671875
# epoch:0,batch loss:0.004985387437045574,batch acc:0.5390625
# epoch:0,batch loss:0.004827911499887705,batch acc:0.46875
# epoch:0,batch loss:0.005622515454888344,batch acc:0.46484375
# epoch:0,batch loss:0.005746197886765003,batch acc:0.3359375
# epoch:0,batch loss:0.005048402119427919,batch acc:0.46875
# epoch:0,batch loss:0.00433127349242568,batch acc:0.58203125
# epoch:0,batch loss:0.005302050616592169,batch acc:0.40625
# epoch:0,batch loss:0.004616140387952328,batch acc:0.53515625
# epoch:0,batch loss:0.005563936196267605,batch acc:0.3828125
# epoch:0,batch loss:0.004138689022511244,batch acc:0.55078125
# epoch:0,batch loss:0.004389364272356033,batch acc:0.51953125
# epoch:0,batch loss:0.0042688497342169285,batch acc:0.55859375
# epoch:0,batch loss:0.00460764579474926,batch acc:0.4765625
# epoch:0,batch loss:0.0056288233026862144,batch acc:0.43359375
# epoch:0,batch loss:0.004635424353182316,batch acc:0.46484375
# epoch:0,batch loss:0.004868670366704464,batch acc:0.546875
# epoch:0,batch loss:0.00510559743270278,batch acc:0.4921875
# epoch:0,batch loss:0.004791333805769682,batch acc:0.5078125
# epoch:0,batch loss:0.004419054836034775,batch acc:0.4765625
# epoch:0,batch loss:0.004947835113853216,batch acc:0.49609375
# epoch:0,batch loss:0.004767614416778088,batch acc:0.48828125
# epoch:0,batch loss:0.0046292319893836975,batch acc:0.53125
# epoch:0,batch loss:0.004381304141134024,batch acc:0.546875
# epoch:0,batch loss:0.004148246720433235,batch acc:0.625
# epoch:0,batch loss:0.004621910396963358,batch acc:0.50390625
# epoch:0,batch loss:0.0049163782969117165,batch acc:0.515625
# epoch:0,batch loss:0.005417852662503719,batch acc:0.51171875
# epoch:0,batch loss:0.004974509123712778,batch acc:0.41796875
# epoch:0,batch loss:0.005787867121398449,batch acc:0.42578125
# epoch:0,batch loss:0.004688737448304892,batch acc:0.5546875
# epoch:0,batch loss:0.004979087971150875,batch acc:0.49609375
# epoch:0,batch loss:0.005083098541945219,batch acc:0.4453125
# epoch:0,batch loss:0.0065413955599069595,batch acc:0.2890625
# epoch:0,batch loss:0.0053551457822322845,batch acc:0.33984375
# epoch:0,batch loss:0.004450351931154728,batch acc:0.54296875
# epoch:0,batch loss:0.006170111708343029,batch acc:0.40234375
# epoch:0,batch loss:0.006754823960363865,batch acc:0.4609375
# epoch:0,batch loss:0.004607309587299824,batch acc:0.4765625
# epoch:0,batch loss:0.005828229710459709,batch acc:0.38671875
# epoch:0,batch loss:0.004760835785418749,batch acc:0.5390625
# epoch:0,batch loss:0.004769440274685621,batch acc:0.484375
# epoch:0,batch loss:0.005149933509528637,batch acc:0.52734375
# epoch:0,batch loss:0.0044066160917282104,batch acc:0.5078125
# epoch:0,batch loss:0.005507053341716528,batch acc:0.53515625
# epoch:0,batch loss:0.005471084266901016,batch acc:0.5078125
# epoch:0,batch loss:0.004682838451117277,batch acc:0.59375
# epoch:0,batch loss:0.006333827041089535,batch acc:0.4609375
# epoch:0,batch loss:0.004751437809318304,batch acc:0.52734375
# epoch:0,batch loss:0.005619629751890898,batch acc:0.37109375
# epoch:0,batch loss:0.005999311339110136,batch acc:0.38671875
# epoch:0,batch loss:0.006635645404458046,batch acc:0.46875
# epoch:0,batch loss:0.005489159841090441,batch acc:0.51171875
# epoch:0,batch loss:0.004969513509422541,batch acc:0.51953125
# epoch:0,batch loss:0.005542463157325983,batch acc:0.421875
# epoch:0,batch loss:0.004966369830071926,batch acc:0.4375
# epoch:0,batch loss:0.005823494400829077,batch acc:0.44921875
# epoch:0,batch loss:0.0054183839820325375,batch acc:0.5
# epoch:0,batch loss:0.006125122308731079,batch acc:0.44921875
# epoch:0,batch loss:0.005138971842825413,batch acc:0.46875
# epoch:0,batch loss:0.005714437924325466,batch acc:0.47265625
# epoch:0,batch loss:0.005240646656602621,batch acc:0.50390625
# epoch:0,batch loss:0.0053090546280145645,batch acc:0.578125
# epoch:0,batch loss:0.007490470539778471,batch acc:0.4296875
# epoch:0,batch loss:0.005689763464033604,batch acc:0.51953125
# epoch:0,batch loss:0.005152072757482529,batch acc:0.5078125
# epoch:0,batch loss:0.005055543966591358,batch acc:0.515625
# epoch:0,batch loss:0.00436199177056551,batch acc:0.5390625
# epoch:0,batch loss:0.004435864742845297,batch acc:0.5859375
# epoch:0,batch loss:0.004357454366981983,batch acc:0.5703125
# epoch:0,batch loss:0.0046506598591804504,batch acc:0.50390625
# epoch:0,batch loss:0.005131978541612625,batch acc:0.45703125
# epoch:0,batch loss:0.004645949695259333,batch acc:0.5546875
# epoch:0,batch loss:0.005529772024601698,batch acc:0.359375
# epoch:0,batch loss:0.00404001260176301,batch acc:0.60546875
# epoch:0,batch loss:0.0053308941423892975,batch acc:0.52734375
# epoch:0,batch loss:0.004544548690319061,batch acc:0.6328125
# epoch:0,batch loss:0.005113555118441582,batch acc:0.5546875
# epoch:0,batch loss:0.0038336662109941244,batch acc:0.65234375
# epoch:0,batch loss:0.004519107285887003,batch acc:0.5546875
# epoch:0,batch loss:0.00508618401363492,batch acc:0.48046875
# epoch:0,batch loss:0.007018029224127531,batch acc:0.40625
# epoch:0,batch loss:0.004996462259441614,batch acc:0.59375
# epoch:0,batch loss:0.00563265522941947,batch acc:0.5390625
# epoch:0,batch loss:0.008147486485540867,batch acc:0.43359375
# epoch:0,batch loss:0.008706810884177685,batch acc:0.40234375
# epoch:0,batch loss:0.005978343542665243,batch acc:0.4765625
# epoch:0,batch loss:0.0054815784096717834,batch acc:0.515625
# epoch:0,batch loss:0.00487771350890398,batch acc:0.48828125
# epoch:0,batch loss:0.00440340768545866,batch acc:0.5625
# epoch:0,batch loss:0.006059916224330664,batch acc:0.44140625
# epoch:0,batch loss:0.004609902389347553,batch acc:0.5625
# epoch:0,batch loss:0.0051019382663071156,batch acc:0.50390625
# epoch:0,batch loss:0.004598553758114576,batch acc:0.51171875
# epoch:0,batch loss:0.005209560506045818,batch acc:0.60546875
# epoch:0,batch loss:0.00487905228510499,batch acc:0.59375
# epoch:0,batch loss:0.005304768681526184,batch acc:0.58984375
# epoch:0,batch loss:0.005058441311120987,batch acc:0.5703125
# epoch:0,batch loss:0.005442992318421602,batch acc:0.50390625
# epoch:0,batch loss:0.005884898826479912,batch acc:0.37109375
# epoch:0,batch loss:0.007584117818623781,batch acc:0.2890625
# epoch:0,batch loss:0.00613853894174099,batch acc:0.41015625
# epoch:0,batch loss:0.004611831158399582,batch acc:0.56640625
# epoch:0,batch loss:0.006273366045206785,batch acc:0.421875
# epoch:0,batch loss:0.008311050944030285,batch acc:0.39453125
# epoch:0,batch loss:0.00680025527253747,batch acc:0.4609375
# epoch:0,batch loss:0.006154455244541168,batch acc:0.44921875
# epoch:0,batch loss:0.006368305534124374,batch acc:0.50390625
# epoch:0,batch loss:0.006532609928399324,batch acc:0.4609375
# epoch:0,batch loss:0.005017727147787809,batch acc:0.578125
# epoch:0,batch loss:0.00812442321330309,batch acc:0.30859375
# epoch:0,batch loss:0.006462858058512211,batch acc:0.453125
# epoch:0,batch loss:0.005701575428247452,batch acc:0.45703125
# epoch:0,batch loss:0.005354374181479216,batch acc:0.58203125
# epoch:0,batch loss:0.005834490992128849,batch acc:0.515625
# epoch:0,batch loss:0.004168097395449877,batch acc:0.640625
# epoch:0,batch loss:0.0065869614481925964,batch acc:0.41796875
# epoch:0,batch loss:0.005760859232395887,batch acc:0.453125
# epoch:0,batch loss:0.005754935555160046,batch acc:0.41015625
# epoch:0,batch loss:0.006128931418061256,batch acc:0.43359375
# epoch:0,batch loss:0.005624283105134964,batch acc:0.46875
# epoch:0,batch loss:0.004893454723060131,batch acc:0.515625
# epoch:0,batch loss:0.0046821958385407925,batch acc:0.453125
# epoch:0,batch loss:0.004932270385324955,batch acc:0.5
# epoch:0,batch loss:0.005665498785674572,batch acc:0.44921875
# epoch:0,batch loss:0.005163365043699741,batch acc:0.55078125
# epoch:0,batch loss:0.004424783866852522,batch acc:0.55859375
# epoch:0,batch loss:0.005181845743209124,batch acc:0.46875
# epoch:0,batch loss:0.004503292962908745,batch acc:0.5546875
# epoch:0,batch loss:0.003840770572423935,batch acc:0.60546875
# epoch:0,batch loss:0.003816264448687434,batch acc:0.63671875
# epoch:0,batch loss:0.004153124056756496,batch acc:0.546875
# epoch:0,batch loss:0.005045199766755104,batch acc:0.546875
# epoch:0,batch loss:0.005530054681003094,batch acc:0.50390625
# epoch:0,batch loss:0.004727867431938648,batch acc:0.53515625
# epoch:0,batch loss:0.004676418378949165,batch acc:0.50390625
# epoch:0,batch loss:0.004654619377106428,batch acc:0.49609375
# epoch:0,batch loss:0.004700975958257914,batch acc:0.4921875
# epoch:0,batch loss:0.0051988461054861546,batch acc:0.4921875
# epoch:0,batch loss:0.0049459077417850494,batch acc:0.46875
# epoch:0,batch loss:0.003899268340319395,batch acc:0.5546875
# epoch:0,batch loss:0.004768492188304663,batch acc:0.55859375
# epoch:0,batch loss:0.0058844867162406445,batch acc:0.3984375
# epoch:0,batch loss:0.004868955351412296,batch acc:0.52734375
# epoch:0,batch loss:0.005712256766855717,batch acc:0.52734375
# epoch:0,batch loss:0.006010978017002344,batch acc:0.4296875
# epoch:0,batch loss:0.005037101451307535,batch acc:0.484375
# epoch:0,batch loss:0.005145273637026548,batch acc:0.47265625
# epoch:0,batch loss:0.0048227012157440186,batch acc:0.5859375
# epoch:0,batch loss:0.003920393064618111,batch acc:0.61328125
# epoch:0,batch loss:0.004809665028005838,batch acc:0.60546875
# epoch:0,batch loss:0.006368495989590883,batch acc:0.49609375
# epoch:0,batch loss:0.005739140324294567,batch acc:0.46875
# epoch:0,batch loss:0.004711824003607035,batch acc:0.58203125
# epoch:0,batch loss:0.0039607263170182705,batch acc:0.62890625
# epoch:0,batch loss:0.006308913230895996,batch acc:0.328125
# epoch:0,batch loss:0.0048654512502253056,batch acc:0.4921875
# epoch:0,batch loss:0.006403218489140272,batch acc:0.46875
# epoch:0,batch loss:0.006007636897265911,batch acc:0.3828125
# epoch:0,batch loss:0.004336914978921413,batch acc:0.546875
# epoch:0,batch loss:0.003974737599492073,batch acc:0.59375
# epoch:0,batch loss:0.0043399096466600895,batch acc:0.4765625
# epoch:0,batch loss:0.005072284955531359,batch acc:0.52734375
# epoch:0,batch loss:0.005825936794281006,batch acc:0.4609375
# epoch:0,batch loss:0.004406288731843233,batch acc:0.484375
# epoch:0,batch loss:0.004922064021229744,batch acc:0.42578125
# epoch:0,batch loss:0.005149986129254103,batch acc:0.45703125
# epoch:0,batch loss:0.004686205647885799,batch acc:0.56640625
# epoch:0,batch loss:0.004911147058010101,batch acc:0.625
# epoch:0,batch loss:0.00456546014174819,batch acc:0.5703125
# epoch:0,batch loss:0.004855327308177948,batch acc:0.515625
# epoch:0,batch loss:0.004240321461111307,batch acc:0.53515625
# epoch:0,batch loss:0.004565228708088398,batch acc:0.58203125
# epoch:0,batch loss:0.005142234731465578,batch acc:0.47265625
# epoch:0,batch loss:0.005126929841935635,batch acc:0.53515625
# epoch 1
# epoch:1,batch loss:0.004512133542448282,batch acc:0.51953125
# epoch:1,batch loss:0.005346396472305059,batch acc:0.46875
# epoch:1,batch loss:0.004490575287491083,batch acc:0.58203125
# epoch:1,batch loss:0.00478377053514123,batch acc:0.5703125
# epoch:1,batch loss:0.004914525430649519,batch acc:0.59375
# epoch:1,batch loss:0.005860541015863419,batch acc:0.4140625
# epoch:1,batch loss:0.004902213346213102,batch acc:0.515625
# epoch:1,batch loss:0.006094846408814192,batch acc:0.46484375
# epoch:1,batch loss:0.005114545114338398,batch acc:0.484375
# epoch:1,batch loss:0.005426889285445213,batch acc:0.60546875
# epoch:1,batch loss:0.005315479822456837,batch acc:0.5078125
# epoch:1,batch loss:0.005188128910958767,batch acc:0.46875
# epoch:1,batch loss:0.004650013521313667,batch acc:0.5234375
# epoch:1,batch loss:0.005291544832289219,batch acc:0.55078125
# epoch:1,batch loss:0.004929474554955959,batch acc:0.55859375
# epoch:1,batch loss:0.006019103340804577,batch acc:0.5
# epoch:1,batch loss:0.006498669274151325,batch acc:0.4296875
# epoch:1,batch loss:0.004036446567624807,batch acc:0.609375
# epoch:1,batch loss:0.005328803788870573,batch acc:0.39453125
# epoch:1,batch loss:0.005085041746497154,batch acc:0.54296875
# epoch:1,batch loss:0.005123852752149105,batch acc:0.5625
# epoch:1,batch loss:0.00504966638982296,batch acc:0.49609375
# epoch:1,batch loss:0.006242319010198116,batch acc:0.3828125
# epoch:1,batch loss:0.004918444436043501,batch acc:0.49609375
# epoch:1,batch loss:0.004710695240646601,batch acc:0.453125
# epoch:1,batch loss:0.005146386567503214,batch acc:0.4609375
# epoch:1,batch loss:0.004479515831917524,batch acc:0.515625
# epoch:1,batch loss:0.0040526073426008224,batch acc:0.609375
# epoch:1,batch loss:0.004728473722934723,batch acc:0.4609375
# epoch:1,batch loss:0.005354565568268299,batch acc:0.484375
# epoch:1,batch loss:0.004506339784711599,batch acc:0.52734375
# epoch:1,batch loss:0.004310533870011568,batch acc:0.546875
# epoch:1,batch loss:0.004110374487936497,batch acc:0.55078125
# epoch:1,batch loss:0.00436145206913352,batch acc:0.55859375
# epoch:1,batch loss:0.005670125130563974,batch acc:0.421875
# epoch:1,batch loss:0.004898861050605774,batch acc:0.44921875
# epoch:1,batch loss:0.004565723706036806,batch acc:0.59375
# epoch:1,batch loss:0.006044190376996994,batch acc:0.47265625
# epoch:1,batch loss:0.004365521017462015,batch acc:0.609375
# epoch:1,batch loss:0.004684461280703545,batch acc:0.50390625
# epoch:1,batch loss:0.005630970932543278,batch acc:0.53515625
# epoch:1,batch loss:0.0059325117617845535,batch acc:0.5234375
# epoch:1,batch loss:0.004942508414387703,batch acc:0.53125
# epoch:1,batch loss:0.004025202710181475,batch acc:0.5546875
# epoch:1,batch loss:0.005028069484978914,batch acc:0.46484375
# epoch:1,batch loss:0.004320776090025902,batch acc:0.546875
# epoch:1,batch loss:0.0047475239261984825,batch acc:0.54296875
# epoch:1,batch loss:0.00432566087692976,batch acc:0.58984375
# epoch:1,batch loss:0.0048995716497302055,batch acc:0.5625
# epoch:1,batch loss:0.0045763845555484295,batch acc:0.54296875
# epoch:1,batch loss:0.0038481985684484243,batch acc:0.62109375
# epoch:1,batch loss:0.0047019426710903645,batch acc:0.45703125
# epoch:1,batch loss:0.004871265962719917,batch acc:0.54296875
# epoch:1,batch loss:0.004909677896648645,batch acc:0.5078125
# epoch:1,batch loss:0.0044630784541368484,batch acc:0.51171875
# epoch:1,batch loss:0.004694380797445774,batch acc:0.50390625
# epoch:1,batch loss:0.004287846852093935,batch acc:0.5703125
# epoch:1,batch loss:0.004342895932495594,batch acc:0.53515625
# epoch:1,batch loss:0.004897905047982931,batch acc:0.546875
# epoch:1,batch loss:0.0065155490301549435,batch acc:0.4140625
# epoch:1,batch loss:0.004885680973529816,batch acc:0.49609375
# epoch:1,batch loss:0.0044617196545004845,batch acc:0.53125
# epoch:1,batch loss:0.0046678464859724045,batch acc:0.5078125
# epoch:1,batch loss:0.005128349643200636,batch acc:0.4765625
# epoch:1,batch loss:0.005906708538532257,batch acc:0.46484375
# epoch:1,batch loss:0.004909747280180454,batch acc:0.4609375
# epoch:1,batch loss:0.005207641515880823,batch acc:0.3359375
# epoch:1,batch loss:0.004752951208502054,batch acc:0.50390625
# epoch:1,batch loss:0.00395743316039443,batch acc:0.578125
# epoch:1,batch loss:0.003843953600153327,batch acc:0.62109375
# epoch:1,batch loss:0.004758951719850302,batch acc:0.52734375
# epoch:1,batch loss:0.004151474218815565,batch acc:0.58984375
# epoch:1,batch loss:0.0051292553544044495,batch acc:0.40625
# epoch:1,batch loss:0.005104737356305122,batch acc:0.4140625
# epoch:1,batch loss:0.00497056869789958,batch acc:0.578125
# epoch:1,batch loss:0.0052916561253368855,batch acc:0.45703125
# epoch:1,batch loss:0.005349909886717796,batch acc:0.4921875
# epoch:1,batch loss:0.005616248119622469,batch acc:0.39453125
# epoch:1,batch loss:0.005172159522771835,batch acc:0.421875
# epoch:1,batch loss:0.005678132642060518,batch acc:0.43359375
# epoch:1,batch loss:0.003981696907430887,batch acc:0.66015625
# epoch:1,batch loss:0.00786399096250534,batch acc:0.50390625
# epoch:1,batch loss:0.004574664402753115,batch acc:0.609375
# epoch:1,batch loss:0.0059600588865578175,batch acc:0.45703125
# epoch:1,batch loss:0.004799844231456518,batch acc:0.45703125
# epoch:1,batch loss:0.005888896528631449,batch acc:0.4375
# epoch:1,batch loss:0.0050939940847456455,batch acc:0.5546875
# epoch:1,batch loss:0.005615863483399153,batch acc:0.60546875
# epoch:1,batch loss:0.004281793721020222,batch acc:0.62890625
# epoch:1,batch loss:0.005106198601424694,batch acc:0.48046875
# epoch:1,batch loss:0.007553271017968655,batch acc:0.32421875
# epoch:1,batch loss:0.005223208572715521,batch acc:0.46875
# epoch:1,batch loss:0.005578288342803717,batch acc:0.453125
# epoch:1,batch loss:0.005028884392231703,batch acc:0.52734375
# epoch:1,batch loss:0.0063869827426970005,batch acc:0.48828125
# epoch:1,batch loss:0.006375138182193041,batch acc:0.40234375
# epoch:1,batch loss:0.004791081417351961,batch acc:0.53125
# epoch:1,batch loss:0.005055211018770933,batch acc:0.5625
# epoch:1,batch loss:0.0043872869573533535,batch acc:0.6015625
# epoch:1,batch loss:0.0057851169258356094,batch acc:0.4453125
# epoch:1,batch loss:0.005934896878898144,batch acc:0.56640625
# epoch:1,batch loss:0.005645789671689272,batch acc:0.48828125
# epoch:1,batch loss:0.00517211202532053,batch acc:0.4765625
# epoch:1,batch loss:0.004352238029241562,batch acc:0.60546875
# epoch:1,batch loss:0.005078314803540707,batch acc:0.546875
# epoch:1,batch loss:0.004167362116277218,batch acc:0.56640625
# epoch:1,batch loss:0.004973645322024822,batch acc:0.5
# epoch:1,batch loss:0.004619214218109846,batch acc:0.54296875
# epoch:1,batch loss:0.004720298573374748,batch acc:0.48828125
# epoch:1,batch loss:0.005033957306295633,batch acc:0.44140625
# epoch:1,batch loss:0.004502553027123213,batch acc:0.55859375
# epoch:1,batch loss:0.004929438699036837,batch acc:0.51953125
# epoch:1,batch loss:0.004129989538341761,batch acc:0.578125
# epoch:1,batch loss:0.00480160815641284,batch acc:0.5
# epoch:1,batch loss:0.005396400578320026,batch acc:0.515625
# epoch:1,batch loss:0.0044902921654284,batch acc:0.5625
# epoch:1,batch loss:0.0056322733871638775,batch acc:0.39453125
# epoch:1,batch loss:0.003935576882213354,batch acc:0.65625
# epoch:1,batch loss:0.0049974252469837666,batch acc:0.51953125
# epoch:1,batch loss:0.004108819644898176,batch acc:0.60546875
# epoch:1,batch loss:0.005239806137979031,batch acc:0.44921875
# epoch:1,batch loss:0.004514483734965324,batch acc:0.51171875
# epoch:1,batch loss:0.0055298092775046825,batch acc:0.57421875
# epoch:1,batch loss:0.005549774505198002,batch acc:0.4921875
# epoch:1,batch loss:0.005537784658372402,batch acc:0.46484375
# epoch:1,batch loss:0.004740248434245586,batch acc:0.47265625
# epoch:1,batch loss:0.005824852269142866,batch acc:0.3515625
# epoch:1,batch loss:0.004810788203030825,batch acc:0.48046875
# epoch:1,batch loss:0.004965899512171745,batch acc:0.57421875
# epoch:1,batch loss:0.007022111210972071,batch acc:0.45703125
# epoch:1,batch loss:0.006075686775147915,batch acc:0.5234375
# epoch:1,batch loss:0.0042374045588076115,batch acc:0.5390625
# epoch:1,batch loss:0.005961524788290262,batch acc:0.34375
# epoch:1,batch loss:0.0052697909995913506,batch acc:0.44921875
# epoch:1,batch loss:0.00521338265389204,batch acc:0.51953125
# epoch:1,batch loss:0.005589321255683899,batch acc:0.4921875
# epoch:1,batch loss:0.004838842898607254,batch acc:0.546875
# epoch:1,batch loss:0.004255193285644054,batch acc:0.49609375
# epoch:1,batch loss:0.005330749787390232,batch acc:0.41015625
# epoch:1,batch loss:0.005081044975668192,batch acc:0.48828125
# epoch:1,batch loss:0.004924132023006678,batch acc:0.58203125
# epoch:1,batch loss:0.006192437838762999,batch acc:0.58984375
# epoch:1,batch loss:0.004657582379877567,batch acc:0.55078125
# epoch:1,batch loss:0.005967131350189447,batch acc:0.48046875
# epoch:1,batch loss:0.003552310634404421,batch acc:0.6015625
# epoch:1,batch loss:0.0037428252398967743,batch acc:0.6171875
# epoch:1,batch loss:0.004958477336913347,batch acc:0.4921875
# epoch:1,batch loss:0.005380687769502401,batch acc:0.5078125
# epoch:1,batch loss:0.005093214102089405,batch acc:0.48828125
# epoch:1,batch loss:0.00596155459061265,batch acc:0.41015625
# epoch:1,batch loss:0.004430484026670456,batch acc:0.55859375
# epoch:1,batch loss:0.0064907618798315525,batch acc:0.35546875
# epoch:1,batch loss:0.006470796652138233,batch acc:0.49609375
# epoch:1,batch loss:0.004606808535754681,batch acc:0.5390625
# epoch:1,batch loss:0.0055769337341189384,batch acc:0.40625
# epoch:1,batch loss:0.004653777461498976,batch acc:0.4609375
# epoch:1,batch loss:0.0039179059676826,batch acc:0.625
# epoch:1,batch loss:0.0052351211197674274,batch acc:0.48828125
# epoch:1,batch loss:0.0052757058292627335,batch acc:0.50390625
# epoch:1,batch loss:0.00442878995090723,batch acc:0.515625
# epoch:1,batch loss:0.0046088420785963535,batch acc:0.41015625
# epoch:1,batch loss:0.0040741730481386185,batch acc:0.5234375
# epoch:1,batch loss:0.004732441157102585,batch acc:0.49609375
# epoch:1,batch loss:0.004385835025459528,batch acc:0.5546875
# epoch:1,batch loss:0.0044501000083982944,batch acc:0.578125
# epoch:1,batch loss:0.0042333221063017845,batch acc:0.578125
# epoch:1,batch loss:0.004079926759004593,batch acc:0.6328125
# epoch:1,batch loss:0.004518964793533087,batch acc:0.54296875
# epoch:1,batch loss:0.0051525654271245,batch acc:0.4140625
# epoch:1,batch loss:0.004549108445644379,batch acc:0.50390625
# epoch:1,batch loss:0.0045837233774363995,batch acc:0.56640625
# epoch:1,batch loss:0.0037901990581303835,batch acc:0.60546875
# epoch:1,batch loss:0.006406831555068493,batch acc:0.5078125
# epoch:1,batch loss:0.005724485497921705,batch acc:0.5234375
# epoch:1,batch loss:0.006267927587032318,batch acc:0.5234375
# epoch:1,batch loss:0.005879563745111227,batch acc:0.49609375
# epoch:1,batch loss:0.004894452169537544,batch acc:0.5546875
# epoch:1,batch loss:0.00590958958491683,batch acc:0.4296875
# epoch:1,batch loss:0.006159399636089802,batch acc:0.52734375
# epoch:1,batch loss:0.004574434366077185,batch acc:0.609375
# epoch:1,batch loss:0.005444427020847797,batch acc:0.453125
# epoch:1,batch loss:0.005639327690005302,batch acc:0.53125
# epoch:1,batch loss:0.0056822095066308975,batch acc:0.50390625
# epoch:1,batch loss:0.005247490014880896,batch acc:0.5546875
# epoch:1,batch loss:0.00470860255882144,batch acc:0.54296875
# epoch:1,batch loss:0.005242086015641689,batch acc:0.48828125
# epoch:1,batch loss:0.005457527469843626,batch acc:0.44921875
# epoch:1,batch loss:0.004874674137681723,batch acc:0.453125
# epoch:1,batch loss:0.005692942067980766,batch acc:0.3828125
# epoch:1,batch loss:0.005198195576667786,batch acc:0.4765625
# epoch:1,batch loss:0.006197857204824686,batch acc:0.46484375
# epoch:1,batch loss:0.005447116214782,batch acc:0.45703125
# epoch:1,batch loss:0.004528677556663752,batch acc:0.5546875
# epoch:1,batch loss:0.004937546793371439,batch acc:0.49609375
# epoch:1,batch loss:0.0052092596888542175,batch acc:0.53515625
# epoch:1,batch loss:0.005779128056019545,batch acc:0.515625
# epoch:1,batch loss:0.006196602713316679,batch acc:0.5
# epoch:1,batch loss:0.004949189722537994,batch acc:0.6171875
# epoch:1,batch loss:0.005156266037374735,batch acc:0.51171875
# epoch:1,batch loss:0.004751219879835844,batch acc:0.5625
# epoch:1,batch loss:0.005038043949753046,batch acc:0.4453125
# epoch:1,batch loss:0.004993502516299486,batch acc:0.453125
# epoch:1,batch loss:0.004187736660242081,batch acc:0.55078125
# epoch:1,batch loss:0.004497970454394817,batch acc:0.546875
# epoch:1,batch loss:0.004635679069906473,batch acc:0.60546875
# epoch:1,batch loss:0.004253738094121218,batch acc:0.62890625
# epoch:1,batch loss:0.004401445854455233,batch acc:0.57421875
# epoch:1,batch loss:0.0040942709892988205,batch acc:0.609375
# epoch:1,batch loss:0.0040530795231461525,batch acc:0.6171875
# epoch:1,batch loss:0.005051269195973873,batch acc:0.47265625
# epoch:1,batch loss:0.005537504330277443,batch acc:0.5234375
# epoch:1,batch loss:0.003980810288339853,batch acc:0.59765625
# epoch:1,batch loss:0.004514163359999657,batch acc:0.55078125
# epoch:1,batch loss:0.005301564000546932,batch acc:0.4609375
# epoch:1,batch loss:0.004458727780729532,batch acc:0.58203125
# epoch:1,batch loss:0.005171008873730898,batch acc:0.54296875
# epoch:1,batch loss:0.004462497774511576,batch acc:0.48828125
# epoch:1,batch loss:0.004396921023726463,batch acc:0.51953125
# epoch:1,batch loss:0.005110298283398151,batch acc:0.453125
# epoch:1,batch loss:0.0047295293770730495,batch acc:0.546875
# epoch:1,batch loss:0.003960828296840191,batch acc:0.62890625
# epoch:1,batch loss:0.0038813131395727396,batch acc:0.5546875
# epoch:1,batch loss:0.005359879229217768,batch acc:0.46875
# epoch:1,batch loss:0.0051131946966052055,batch acc:0.5
# epoch:1,batch loss:0.004707766231149435,batch acc:0.4375
# epoch:1,batch loss:0.0044430457055568695,batch acc:0.609375
# epoch:1,batch loss:0.004142033401876688,batch acc:0.6171875
# epoch:1,batch loss:0.004932391457259655,batch acc:0.46875
# epoch:1,batch loss:0.0054444316774606705,batch acc:0.52734375
# epoch:1,batch loss:0.004893834702670574,batch acc:0.41015625
# epoch:1,batch loss:0.005465611349791288,batch acc:0.39453125
# epoch:1,batch loss:0.004180357791483402,batch acc:0.60546875
# epoch:1,batch loss:0.005963870324194431,batch acc:0.515625
# epoch:1,batch loss:0.00462039839476347,batch acc:0.5703125
# epoch:1,batch loss:0.005131992511451244,batch acc:0.5390625
# epoch:1,batch loss:0.005374355241656303,batch acc:0.57421875
# epoch:1,batch loss:0.004291972145438194,batch acc:0.54296875
# epoch:1,batch loss:0.0046418095007538795,batch acc:0.58203125
# epoch:1,batch loss:0.0047039189375936985,batch acc:0.54296875
# epoch:1,batch loss:0.004610266536474228,batch acc:0.578125
# epoch:1,batch loss:0.005986138712614775,batch acc:0.42578125
# epoch:1,batch loss:0.004782260861247778,batch acc:0.49609375
# epoch:1,batch loss:0.005898023955523968,batch acc:0.4140625
# epoch:1,batch loss:0.005917479749768972,batch acc:0.39453125
# epoch:1,batch loss:0.004571884870529175,batch acc:0.47265625
# epoch:1,batch loss:0.004388249013572931,batch acc:0.58203125
# epoch:1,batch loss:0.005118962377309799,batch acc:0.5546875
# epoch:1,batch loss:0.0055466038174927235,batch acc:0.51171875
# epoch:1,batch loss:0.005533615127205849,batch acc:0.4921875
# epoch:1,batch loss:0.004662070423364639,batch acc:0.46875
# epoch:1,batch loss:0.005077180918306112,batch acc:0.4765625
# epoch:1,batch loss:0.0042959856800735,batch acc:0.60546875
# epoch:1,batch loss:0.004231725819408894,batch acc:0.61328125
# epoch:1,batch loss:0.004333057906478643,batch acc:0.58984375
# epoch:1,batch loss:0.004390086978673935,batch acc:0.55078125
# epoch:1,batch loss:0.004615739453583956,batch acc:0.53515625
# epoch:1,batch loss:0.004719789605587721,batch acc:0.45703125
# epoch:1,batch loss:0.004286917857825756,batch acc:0.578125
# epoch:1,batch loss:0.004973358009010553,batch acc:0.625
# epoch:1,batch loss:0.005426967982202768,batch acc:0.54296875
# epoch:1,batch loss:0.00488246139138937,batch acc:0.5078125
# epoch:1,batch loss:0.004608897492289543,batch acc:0.5625
# epoch:1,batch loss:0.005228014197200537,batch acc:0.453125
# epoch:1,batch loss:0.004503058735281229,batch acc:0.5234375
# epoch:1,batch loss:0.004682695958763361,batch acc:0.5
# epoch:1,batch loss:0.005589138716459274,batch acc:0.53125
# epoch:1,batch loss:0.0056604864075779915,batch acc:0.421875
# epoch:1,batch loss:0.0044855535961687565,batch acc:0.53125
# epoch:1,batch loss:0.003952945116907358,batch acc:0.6015625
# epoch:1,batch loss:0.005253582261502743,batch acc:0.484375
# epoch:1,batch loss:0.004627391695976257,batch acc:0.57421875
# epoch:1,batch loss:0.005339139141142368,batch acc:0.453125
# epoch:1,batch loss:0.003773229196667671,batch acc:0.6484375
# epoch:1,batch loss:0.00433397525921464,batch acc:0.5625
# epoch:1,batch loss:0.003947102464735508,batch acc:0.625
# epoch:1,batch loss:0.0049058725126087666,batch acc:0.51171875
# epoch:1,batch loss:0.005440481472760439,batch acc:0.43359375
# epoch:1,batch loss:0.0044122906401753426,batch acc:0.5234375
# epoch:1,batch loss:0.004654671531170607,batch acc:0.52734375
# epoch:1,batch loss:0.005059987772256136,batch acc:0.53125
# epoch:1,batch loss:0.004846097901463509,batch acc:0.5390625
# epoch:1,batch loss:0.003830003086477518,batch acc:0.63671875
# epoch:1,batch loss:0.004960854537785053,batch acc:0.54296875
# epoch:1,batch loss:0.004854473285377026,batch acc:0.46875
# epoch:1,batch loss:0.004106059204787016,batch acc:0.56640625
# epoch:1,batch loss:0.004284274764358997,batch acc:0.5078125
# epoch:1,batch loss:0.004388928413391113,batch acc:0.609375
# epoch:1,batch loss:0.004709878005087376,batch acc:0.48828125
# epoch:1,batch loss:0.0046523441560566425,batch acc:0.5078125
# epoch:1,batch loss:0.005169649608433247,batch acc:0.4453125
# epoch:1,batch loss:0.004827815108001232,batch acc:0.48046875
# epoch:1,batch loss:0.0054011414758861065,batch acc:0.5234375
# epoch:1,batch loss:0.004698184318840504,batch acc:0.60546875
# epoch:1,batch loss:0.005192883312702179,batch acc:0.49609375
# epoch:1,batch loss:0.005220907274633646,batch acc:0.4375
# epoch:1,batch loss:0.006055975332856178,batch acc:0.36328125
# epoch:1,batch loss:0.005430295597761869,batch acc:0.390625
# epoch:1,batch loss:0.004482722841203213,batch acc:0.5390625
# epoch:1,batch loss:0.006097510457038879,batch acc:0.41015625
# epoch:1,batch loss:0.006854521110653877,batch acc:0.46875
# epoch:1,batch loss:0.004398553166538477,batch acc:0.51953125
# epoch:1,batch loss:0.0048647690564394,batch acc:0.5625
# epoch:1,batch loss:0.005119055975228548,batch acc:0.5546875
# epoch:1,batch loss:0.004693696275353432,batch acc:0.484375
# epoch:1,batch loss:0.0050181797705590725,batch acc:0.5390625
# epoch:1,batch loss:0.004149076994508505,batch acc:0.5390625
# epoch:1,batch loss:0.006681418977677822,batch acc:0.52734375
# epoch:1,batch loss:0.0061186011880636215,batch acc:0.5859375
# epoch:1,batch loss:0.004658044315874577,batch acc:0.59765625
# epoch:1,batch loss:0.005606585647910833,batch acc:0.51171875
# epoch:1,batch loss:0.004790693521499634,batch acc:0.5
# epoch:1,batch loss:0.00815751776099205,batch acc:0.375
# epoch:1,batch loss:0.005931266117841005,batch acc:0.48046875
# epoch:1,batch loss:0.00727194594219327,batch acc:0.39453125
# epoch:1,batch loss:0.005703148897737265,batch acc:0.515625
# epoch:1,batch loss:0.0046648671850562096,batch acc:0.48046875
# epoch:1,batch loss:0.004548756405711174,batch acc:0.5625
# epoch:1,batch loss:0.004979697056114674,batch acc:0.48828125
# epoch:1,batch loss:0.007114279083907604,batch acc:0.36328125
# epoch:1,batch loss:0.0049217394553124905,batch acc:0.5
# epoch:1,batch loss:0.004810079000890255,batch acc:0.5859375
# epoch:1,batch loss:0.004919467493891716,batch acc:0.515625
# epoch:1,batch loss:0.005553334020078182,batch acc:0.48046875
# epoch:1,batch loss:0.005638234317302704,batch acc:0.515625
# epoch:1,batch loss:0.004332891199737787,batch acc:0.64453125
# epoch:1,batch loss:0.006597211584448814,batch acc:0.4453125
# epoch:1,batch loss:0.005569730419665575,batch acc:0.55078125
# epoch:1,batch loss:0.005431075114756823,batch acc:0.375
# epoch:1,batch loss:0.0037637657951563597,batch acc:0.67578125
# epoch:1,batch loss:0.003987633157521486,batch acc:0.57421875
# epoch:1,batch loss:0.004012324381619692,batch acc:0.61328125
# epoch:1,batch loss:0.004208499100059271,batch acc:0.609375
# epoch:1,batch loss:0.0051037403754889965,batch acc:0.546875
# epoch:1,batch loss:0.005034649278968573,batch acc:0.54296875
# epoch:1,batch loss:0.00462972279638052,batch acc:0.4765625
# epoch:1,batch loss:0.005521800369024277,batch acc:0.4296875
# epoch:1,batch loss:0.004781297408044338,batch acc:0.50390625
# epoch:1,batch loss:0.004920918494462967,batch acc:0.6328125
# epoch:1,batch loss:0.0044874753803014755,batch acc:0.609375
# epoch:1,batch loss:0.0042946795001626015,batch acc:0.625
# epoch:1,batch loss:0.004039356019347906,batch acc:0.52734375
# epoch:1,batch loss:0.00430270005017519,batch acc:0.5859375
# epoch:1,batch loss:0.004385098349303007,batch acc:0.5390625
# epoch:1,batch loss:0.0065422686748206615,batch acc:0.5234375
# epoch:1,batch loss:0.005154362414032221,batch acc:0.5859375
# epoch:1,batch loss:0.005220492370426655,batch acc:0.484375
# epoch:1,batch loss:0.0067451042123138905,batch acc:0.40234375
# epoch:1,batch loss:0.00638494361191988,batch acc:0.39453125
# epoch:1,batch loss:0.004501561168581247,batch acc:0.46484375
# epoch:1,batch loss:0.005344119854271412,batch acc:0.51171875
# epoch:1,batch loss:0.005239780060946941,batch acc:0.4609375
# epoch:1,batch loss:0.003900842973962426,batch acc:0.625
# epoch:1,batch loss:0.005259782541543245,batch acc:0.484375
# epoch:1,batch loss:0.00390781881287694,batch acc:0.546875
# epoch:1,batch loss:0.004144861362874508,batch acc:0.4765625
# epoch:1,batch loss:0.004165815655142069,batch acc:0.58984375
# epoch:1,batch loss:0.003968771547079086,batch acc:0.640625
# epoch:1,batch loss:0.004208851605653763,batch acc:0.58984375
# epoch:1,batch loss:0.003402229631319642,batch acc:0.6796875
# epoch:1,batch loss:0.0034120783675462008,batch acc:0.66015625
# epoch:1,batch loss:0.005123538430780172,batch acc:0.56640625
# epoch:1,batch loss:0.005358113907277584,batch acc:0.4609375
# ...
# epoch:29,batch loss:0.0025638225488364697,batch acc:0.73046875
# epoch:29,batch loss:0.0025215228088200092,batch acc:0.8125
# epoch:29,batch loss:0.002002689754590392,batch acc:0.796875
# epoch:29,batch loss:0.0017884965054690838,batch acc:0.796875
# epoch:29,batch loss:0.0019012474222108722,batch acc:0.82421875
# epoch:29,batch loss:0.0022697490639984608,batch acc:0.76953125
# epoch:29,batch loss:0.002276696963235736,batch acc:0.76953125
# epoch:29,batch loss:0.00203393935225904,batch acc:0.8046875
# epoch:29,batch loss:0.0033138112630695105,batch acc:0.63671875
# epoch:29,batch loss:0.0028888038359582424,batch acc:0.7421875
# epoch:29,batch loss:0.001863403944298625,batch acc:0.796875
# epoch:29,batch loss:0.00169789744541049,batch acc:0.80859375
# epoch:29,batch loss:0.0017545294249430299,batch acc:0.85546875
# epoch:29,batch loss:0.002169125946238637,batch acc:0.78125
# epoch:29,batch loss:0.0022496504243463278,batch acc:0.76171875
# epoch:29,batch loss:0.0020837991032749414,batch acc:0.7578125
# epoch:29,batch loss:0.0034972524736076593,batch acc:0.7109375
# epoch:29,batch loss:0.0034830449149012566,batch acc:0.69140625
# epoch:29,batch loss:0.002634417498484254,batch acc:0.76953125
# epoch:29,batch loss:0.00264865905046463,batch acc:0.71484375
# epoch:29,batch loss:0.0018485202454030514,batch acc:0.80078125
# epoch:29,batch loss:0.0018231092253699899,batch acc:0.79296875
# epoch:29,batch loss:0.0017172127263620496,batch acc:0.86328125
# epoch:29,batch loss:0.001731492462567985,batch acc:0.82421875
# epoch:29,batch loss:0.001998803811147809,batch acc:0.7265625
# epoch:29,batch loss:0.002131215063855052,batch acc:0.71484375
# epoch:29,batch loss:0.00231817620806396,batch acc:0.7265625
# epoch:29,batch loss:0.002170784631744027,batch acc:0.7890625
# epoch:29,batch loss:0.0015456218970939517,batch acc:0.85546875
# epoch:29,batch loss:0.001686480245552957,batch acc:0.80078125
# epoch:29,batch loss:0.0018152367556467652,batch acc:0.8125
# epoch:29,batch loss:0.002109816763550043,batch acc:0.82421875
# epoch:29,batch loss:0.002109594875946641,batch acc:0.8046875
# epoch:29,batch loss:0.001774384523741901,batch acc:0.84375
# epoch:29,batch loss:0.002493565436452627,batch acc:0.734375
# epoch:29,batch loss:0.002725798636674881,batch acc:0.77734375
# epoch:29,batch loss:0.0016778307035565376,batch acc:0.87109375
# epoch:29,batch loss:0.0014660110464319587,batch acc:0.859375
# epoch:29,batch loss:0.0016982208471745253,batch acc:0.82421875
# epoch:29,batch loss:0.0017874594777822495,batch acc:0.828125
# epoch:29,batch loss:0.0018401095876470208,batch acc:0.81640625
# epoch:29,batch loss:0.0014982600696384907,batch acc:0.8671875
# epoch:29,batch loss:0.0016522454097867012,batch acc:0.8359375
# epoch:29,batch loss:0.002274750266224146,batch acc:0.81640625
# epoch:29,batch loss:0.0031969656702131033,batch acc:0.75390625
# epoch:29,batch loss:0.002072604140266776,batch acc:0.765625
# epoch:29,batch loss:0.002269600285217166,batch acc:0.7890625
# epoch:29,batch loss:0.0026510893367230892,batch acc:0.80859375
# epoch:29,batch loss:0.002455814741551876,batch acc:0.796875
# epoch:29,batch loss:0.001789998495951295,batch acc:0.84375
# epoch:29,batch loss:0.0038292573299258947,batch acc:0.67578125
# epoch:29,batch loss:0.0025564476381987333,batch acc:0.75
# epoch:29,batch loss:0.001447849441319704,batch acc:0.859375
# epoch:29,batch loss:0.002284539397805929,batch acc:0.7734375
# epoch:29,batch loss:0.002179314848035574,batch acc:0.7890625
# epoch:29,batch loss:0.0014991549542173743,batch acc:0.8203125
# epoch:29,batch loss:0.0016605814453214407,batch acc:0.859375
# epoch:29,batch loss:0.002757532522082329,batch acc:0.73828125
# epoch:29,batch loss:0.0020835353061556816,batch acc:0.7734375
# epoch:29,batch loss:0.001556582748889923,batch acc:0.8671875
# epoch:29,batch loss:0.002439422532916069,batch acc:0.76953125
# epoch:29,batch loss:0.0015641598729416728,batch acc:0.85546875
# epoch:29,batch loss:0.0024604329373687506,batch acc:0.77734375
# epoch:29,batch loss:0.0024549993686378,batch acc:0.7578125
# epoch:29,batch loss:0.0023319467436522245,batch acc:0.828125
# epoch:29,batch loss:0.0019671618938446045,batch acc:0.8203125
# epoch:29,batch loss:0.002829306060448289,batch acc:0.6875
# epoch:29,batch loss:0.0032015119213610888,batch acc:0.6328125
# epoch:29,batch loss:0.0024795974604785442,batch acc:0.7578125
# epoch:29,batch loss:0.0018998795421794057,batch acc:0.765625
# epoch:29,batch loss:0.005261954385787249,batch acc:0.69140625
# epoch:29,batch loss:0.002513943472877145,batch acc:0.765625
# epoch:29,batch loss:0.0014808981213718653,batch acc:0.8671875
# epoch:29,batch loss:0.0020365603268146515,batch acc:0.78125
# epoch:29,batch loss:0.004590069409459829,batch acc:0.5546875
# epoch:29,batch loss:0.001959790475666523,batch acc:0.80078125
# epoch:29,batch loss:0.0020654809195548296,batch acc:0.75390625
# epoch:29,batch loss:0.004341887775808573,batch acc:0.58984375
# epoch:29,batch loss:0.007531057111918926,batch acc:0.59375
# epoch:29,batch loss:0.0024284229148179293,batch acc:0.76171875
# epoch:29,batch loss:0.005906211212277412,batch acc:0.78125
# epoch:29,batch loss:0.0026441626250743866,batch acc:0.7578125
# epoch:29,batch loss:0.002845011418685317,batch acc:0.77734375
# epoch:29,batch loss:0.003660743124783039,batch acc:0.734375
# epoch:29,batch loss:0.0038476670160889626,batch acc:0.68359375
# epoch:29,batch loss:0.0028636509086936712,batch acc:0.76171875
# epoch:29,batch loss:0.0034890729002654552,batch acc:0.75
# epoch:29,batch loss:0.003087621182203293,batch acc:0.72265625
# epoch:29,batch loss:0.0030487317126244307,batch acc:0.671875
# epoch:29,batch loss:0.0023202497977763414,batch acc:0.78125
# epoch:29,batch loss:0.0023409591522067785,batch acc:0.7890625
# epoch:29,batch loss:0.0026957672089338303,batch acc:0.7890625
# epoch:29,batch loss:0.0021893989760428667,batch acc:0.77734375
# epoch:29,batch loss:0.0032457937486469746,batch acc:0.6875
# epoch:29,batch loss:0.002486752811819315,batch acc:0.76953125
# epoch:29,batch loss:0.0023741719778627157,batch acc:0.75390625
# epoch:29,batch loss:0.001861582393757999,batch acc:0.80078125
# epoch:29,batch loss:0.002753180917352438,batch acc:0.7421875
# epoch:29,batch loss:0.002047530608251691,batch acc:0.796875
# epoch:29,batch loss:0.002278686501085758,batch acc:0.78515625
# epoch:29,batch loss:0.0028362292796373367,batch acc:0.65234375
# epoch:29,batch loss:0.002390125300735235,batch acc:0.75
# epoch:29,batch loss:0.0030276444740593433,batch acc:0.765625
# epoch:29,batch loss:0.002052449621260166,batch acc:0.796875
# epoch:29,batch loss:0.003023154102265835,batch acc:0.65625
# epoch:29,batch loss:0.0019478496396914124,batch acc:0.78515625
# epoch:29,batch loss:0.0014833958121016622,batch acc:0.85546875
# epoch:29,batch loss:0.0021487802732735872,batch acc:0.75390625
# epoch:29,batch loss:0.0017883393447846174,batch acc:0.82421875
# epoch:29,batch loss:0.0020803255029022694,batch acc:0.765625
# epoch:29,batch loss:0.002117014490067959,batch acc:0.78515625
# epoch:29,batch loss:0.0019472652347758412,batch acc:0.796875
# epoch:29,batch loss:0.0021832056809216738,batch acc:0.8125
# epoch:29,batch loss:0.0027293178718537092,batch acc:0.7265625
# epoch:29,batch loss:0.002417259616777301,batch acc:0.77734375
# epoch:29,batch loss:0.0023659111466258764,batch acc:0.76171875
# epoch:29,batch loss:0.002444480312988162,batch acc:0.75
# epoch:29,batch loss:0.0020413356833159924,batch acc:0.796875
# epoch:29,batch loss:0.0029371173586696386,batch acc:0.71484375
# epoch:29,batch loss:0.0019825189374387264,batch acc:0.828125
# epoch:29,batch loss:0.0019091976573690772,batch acc:0.77734375
# epoch:29,batch loss:0.0029873044695705175,batch acc:0.6953125
# epoch:29,batch loss:0.0021891300566494465,batch acc:0.75390625
# epoch:29,batch loss:0.0015245029935613275,batch acc:0.8515625
# epoch:29,batch loss:0.0024308771826326847,batch acc:0.68359375
# epoch:29,batch loss:0.002881508320569992,batch acc:0.7265625
# epoch:29,batch loss:0.0024760044179856777,batch acc:0.75
# epoch:29,batch loss:0.001353675965219736,batch acc:0.8359375
# epoch:29,batch loss:0.001772992662154138,batch acc:0.796875
# epoch:29,batch loss:0.0019662610720843077,batch acc:0.7734375
# epoch:29,batch loss:0.0024323672987520695,batch acc:0.78125
# epoch:29,batch loss:0.0019679416436702013,batch acc:0.78125
# epoch:29,batch loss:0.0036232550628483295,batch acc:0.671875
# epoch:29,batch loss:0.0016264718724414706,batch acc:0.8359375
# epoch:29,batch loss:0.0027944492176175117,batch acc:0.73046875
# epoch:29,batch loss:0.001959330402314663,batch acc:0.80078125
# epoch:29,batch loss:0.00207663350738585,batch acc:0.80859375
# epoch:29,batch loss:0.0019151903688907623,batch acc:0.78125
# epoch:29,batch loss:0.0017888883594423532,batch acc:0.8046875
# epoch:29,batch loss:0.0014997943071648479,batch acc:0.84375
# epoch:29,batch loss:0.002159709809347987,batch acc:0.7890625
# epoch:29,batch loss:0.0021575994323939085,batch acc:0.796875
# epoch:29,batch loss:0.0025574006140232086,batch acc:0.7421875
# epoch:29,batch loss:0.0019880717154592276,batch acc:0.8125
# epoch:29,batch loss:0.0014995025703683496,batch acc:0.84765625
# epoch:29,batch loss:0.002460474381223321,batch acc:0.73828125
# epoch:29,batch loss:0.0020961191039532423,batch acc:0.8203125
# epoch:29,batch loss:0.0029112452175468206,batch acc:0.75
# epoch:29,batch loss:0.0023458132054656744,batch acc:0.75390625
# epoch:29,batch loss:0.0022082598879933357,batch acc:0.73046875
# epoch:29,batch loss:0.0015420366544276476,batch acc:0.83203125
# epoch:29,batch loss:0.0020093494094908237,batch acc:0.80078125
# epoch:29,batch loss:0.0016835060669109225,batch acc:0.828125
# epoch:29,batch loss:0.002091334667056799,batch acc:0.78125
# epoch:29,batch loss:0.0020994406659156084,batch acc:0.80859375
# epoch:29,batch loss:0.002476276131346822,batch acc:0.70703125
# epoch:29,batch loss:0.0019348267232999206,batch acc:0.80078125
# epoch:29,batch loss:0.001996326493099332,batch acc:0.7578125
# epoch:29,batch loss:0.0016149431467056274,batch acc:0.84765625
# epoch:29,batch loss:0.002217333996668458,batch acc:0.77734375
# epoch:29,batch loss:0.0024455334059894085,batch acc:0.73046875
# epoch:29,batch loss:0.0020318382885307074,batch acc:0.7890625
# epoch:29,batch loss:0.0023907306604087353,batch acc:0.7265625
# epoch:29,batch loss:0.0014892123872414231,batch acc:0.8671875
# epoch:29,batch loss:0.0012586701195687056,batch acc:0.87109375
# epoch:29,batch loss:0.0018052419181913137,batch acc:0.80859375
# epoch:29,batch loss:0.0023893057368695736,batch acc:0.75390625
# epoch:29,batch loss:0.0023737717419862747,batch acc:0.76953125
# epoch:29,batch loss:0.002461465774103999,batch acc:0.7734375
# epoch:29,batch loss:0.0019087448017671704,batch acc:0.7890625
# epoch:29,batch loss:0.0021380449179559946,batch acc:0.76171875
# epoch:29,batch loss:0.0019447917584329844,batch acc:0.75390625
# epoch:29,batch loss:0.0020836233161389828,batch acc:0.78515625
# epoch:29,batch loss:0.0019192746840417385,batch acc:0.82421875
# epoch:29,batch loss:0.0023794956505298615,batch acc:0.7578125
# epoch:29,batch loss:0.0017981196288019419,batch acc:0.8203125
# epoch:29,batch loss:0.0023294356651604176,batch acc:0.75390625
# epoch:29,batch loss:0.0021019033156335354,batch acc:0.796875
# epoch:29,batch loss:0.0013928108382970095,batch acc:0.828125
# epoch:29,batch loss:0.002024292014539242,batch acc:0.7890625
# epoch:29,batch loss:0.0017195536056533456,batch acc:0.828125
# epoch:29,batch loss:0.0017285371432080865,batch acc:0.8125
# epoch:29,batch loss:0.0022123861126601696,batch acc:0.74609375
# epoch:29,batch loss:0.0018999234307557344,batch acc:0.78515625
# epoch:29,batch loss:0.002276407787576318,batch acc:0.7734375
# epoch:29,batch loss:0.0017983035650104284,batch acc:0.828125
# epoch:29,batch loss:0.0016554241301491857,batch acc:0.83984375
# epoch:29,batch loss:0.0019149113213643432,batch acc:0.82421875
# epoch:29,batch loss:0.0015494198305532336,batch acc:0.80859375
# epoch:29,batch loss:0.001422899542376399,batch acc:0.8515625
# epoch:29,batch loss:0.0019956708420068026,batch acc:0.68359375
# epoch:29,batch loss:0.0020162963774055243,batch acc:0.78125
# epoch:29,batch loss:0.0021468072663992643,batch acc:0.78515625
# epoch:29,batch loss:0.001712302677333355,batch acc:0.8203125
# epoch:29,batch loss:0.0018243506783619523,batch acc:0.828125
# epoch:29,batch loss:0.0020920811221003532,batch acc:0.76171875
# epoch:29,batch loss:0.0018800337566062808,batch acc:0.8046875
# epoch:29,batch loss:0.0019818099681288004,batch acc:0.78125
# epoch:29,batch loss:0.0019433439010754228,batch acc:0.83984375
# epoch:29,batch loss:0.001578791649080813,batch acc:0.83203125
# epoch:29,batch loss:0.0020285595674067736,batch acc:0.8359375
# epoch:29,batch loss:0.002071388065814972,batch acc:0.7890625
# epoch:29,batch loss:0.0018032561056315899,batch acc:0.78515625
# epoch:29,batch loss:0.0016334629617631435,batch acc:0.80078125
# epoch:29,batch loss:0.0017354770097881556,batch acc:0.78125
# epoch:29,batch loss:0.0016433370765298605,batch acc:0.84375
# epoch:29,batch loss:0.0019191594328731298,batch acc:0.83203125
# epoch:29,batch loss:0.0017174301901832223,batch acc:0.80859375
# epoch:29,batch loss:0.0021057575941085815,batch acc:0.81640625
# epoch:29,batch loss:0.00186506612226367,batch acc:0.74609375
# epoch:29,batch loss:0.0015615705633535981,batch acc:0.88671875
# epoch:29,batch loss:0.002016491489484906,batch acc:0.79296875
# epoch:29,batch loss:0.0017546258168295026,batch acc:0.84765625
# epoch:29,batch loss:0.0013754062820225954,batch acc:0.8359375
# epoch:29,batch loss:0.002342655323445797,batch acc:0.80078125
# epoch:29,batch loss:0.002342215506359935,batch acc:0.71875
# epoch:29,batch loss:0.0015965281054377556,batch acc:0.828125
# epoch:29,batch loss:0.001863723387941718,batch acc:0.78515625
# epoch:29,batch loss:0.002175660338252783,batch acc:0.828125
# epoch:29,batch loss:0.0022296630777418613,batch acc:0.75
# epoch:29,batch loss:0.0014064372517168522,batch acc:0.828125
# epoch:29,batch loss:0.0011579429265111685,batch acc:0.83984375
# epoch:29,batch loss:0.0019198184600099921,batch acc:0.8203125
# epoch:29,batch loss:0.0025905517395585775,batch acc:0.7421875
# epoch:29,batch loss:0.0021021408028900623,batch acc:0.8046875
# epoch:29,batch loss:0.001625451142899692,batch acc:0.84375
# epoch:29,batch loss:0.002697663614526391,batch acc:0.71484375
# epoch:29,batch loss:0.001944618416018784,batch acc:0.81640625
# epoch:29,batch loss:0.0017480889800935984,batch acc:0.80078125
# epoch:29,batch loss:0.00255768746137619,batch acc:0.77734375
# epoch:29,batch loss:0.002575075253844261,batch acc:0.73828125
# epoch:29,batch loss:0.0020275511778891087,batch acc:0.8203125
# epoch:29,batch loss:0.0017899720696732402,batch acc:0.81640625
# epoch:29,batch loss:0.001974437851458788,batch acc:0.765625
# epoch:29,batch loss:0.0017383235972374678,batch acc:0.82421875
# epoch:29,batch loss:0.0018042223528027534,batch acc:0.77734375
# epoch:29,batch loss:0.002522885100916028,batch acc:0.73046875
# epoch:29,batch loss:0.0016026783268898726,batch acc:0.81640625
# epoch:29,batch loss:0.0018228325061500072,batch acc:0.828125
# epoch:29,batch loss:0.0016703249420970678,batch acc:0.8359375
# epoch:29,batch loss:0.0015809170436114073,batch acc:0.80859375
# epoch:29,batch loss:0.0023092878982424736,batch acc:0.765625
# epoch:29,batch loss:0.0029137814417481422,batch acc:0.6796875
# epoch:29,batch loss:0.0025498177856206894,batch acc:0.81640625
# epoch:29,batch loss:0.0018656051252037287,batch acc:0.82421875
# epoch:29,batch loss:0.0015637616161257029,batch acc:0.86328125
# epoch:29,batch loss:0.0021761232055723667,batch acc:0.78515625
# epoch:29,batch loss:0.001829782035201788,batch acc:0.84375
# epoch:29,batch loss:0.00132865144405514,batch acc:0.88671875
# epoch:29,batch loss:0.0018817443633452058,batch acc:0.83984375
# epoch:29,batch loss:0.0017637625569477677,batch acc:0.81640625
# epoch:29,batch loss:0.0016429773531854153,batch acc:0.84375
# epoch:29,batch loss:0.0024808235466480255,batch acc:0.76953125
# epoch:29,batch loss:0.0019967972766608,batch acc:0.796875
# epoch:29,batch loss:0.0020481464453041553,batch acc:0.80078125
# epoch:29,batch loss:0.0021058996208012104,batch acc:0.80078125
# epoch:29,batch loss:0.001810676883906126,batch acc:0.75390625
# epoch:29,batch loss:0.0017611375078558922,batch acc:0.78515625
# epoch:29,batch loss:0.001782122766599059,batch acc:0.80859375

# %%
plt.xlabel('Iterations')
plt.ylabel('train loss')
plt.plot(np.arange(len(batch_loss_list)), batch_loss_list)

# %%
plt.xlabel('Iterations')
plt.ylabel('train acc')
plt.plot(np.arange(len(batch_acc_list)), batch_acc_list)

# %% [markdown]
# ## 测试

# %%
def test(model,dataset_x,dataset_y,pred_list,real_list):
    model.eval()
    for i in range(len(dataset_x)):
        X = torch.tensor([dataset_x[i]]).to(device)
        y = torch.tensor([dataset_y[i]]).to(device)
        y_hat = model(X)
        pred_list.append(y_hat.argmax(dim=1).cpu().item())
        real_list.append(y.argmax(dim=1).cpu().item())

# %%
model = torch.load("models/BiLSTM_v3.npy")
pred_list = []
real_list = []
print("testing... ")
test(model,x_test,y_test,pred_list,real_list)
# Out:
# testing...

# %%
print(metrics.classification_report(real_list,pred_list))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.58      0.57      2396
#            1       0.24      0.41      0.31       731
#            2       0.23      0.38      0.29       786
#            3       0.67      0.62      0.64       883
#            4       0.84      0.77      0.80     11256
#
#     accuracy                           0.70     16052
#    macro avg       0.51      0.55      0.52     16052
# weighted avg       0.73      0.70      0.71     16052

# %%
cm = metrics.confusion_matrix(real_list,pred_list)
plot_confusion_matrix(cm,range(5),normalize=True,title='test dataset confusion matrix')
# Out:
# 显示百分比：
# [[ 0.58  0.05  0.04  0.01  0.32]
#  [ 0.12  0.41  0.06  0.03  0.38]
#  [ 0.09  0.08  0.38  0.02  0.43]
#  [ 0.03  0.07  0.02  0.62  0.27]
#  [ 0.08  0.06  0.07  0.02  0.77]]
