# %%
import torch
import torch.nn as nn
from torch.functional import F
from sklearn import metrics
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
# %matplotlib inline
import numpy as np
from utils import plot_confusion_matrix

# %%
x_train = torch.load("dataset/x_train")
y_train = torch.load("dataset/y_train")
x_test = torch.load("dataset/x_test")
y_test = torch.load("dataset/y_test")

# %%
class BiRNN(nn.Module):
    def __init__(self, embed_size, num_hiddens, num_layers, classes):
        super(BiRNN, self).__init__()
        # bidirectional设为True即得到双向循环神经网络

        self.encoder = nn.LSTM(input_size=embed_size,
                               hidden_size=num_hiddens,
                               num_layers=num_layers,
                               bidirectional=True)
        
        # 初始时间步和最终时间步的隐藏状态作为全连接层输入
        self.classifier = nn.Sequential(
            nn.Linear(4*num_hiddens, 128*num_hiddens),
            nn.BatchNorm1d(128*num_hiddens),
            nn.Sigmoid(),
            nn.Linear(128*num_hiddens,classes)
        )


    def forward(self, inputs):
        # inputs的形状是(批量大小, 词数, 词向量维度)，因为LSTM需要将序列长度(seq_len)作为第一维，所以将输入转置后
        # 再提取词特征，输出形状为(词数, 批量大小, 词向量维度)
        inputs = torch.transpose(inputs, 0, 1)
        # outputs形状是(词数, 批量大小, 2 * 隐藏单元个数)
        outputs, _ = self.encoder(inputs)  # output, (h, c)
        # 连结初始时间步和最终时间步的隐藏状态作为全连接层输入。它的形状为 (批量大小, 4 * 隐藏单元个数)。
        outs = torch.cat((outputs[0], outputs[-1]), -1)
        outs = self.classifier(outs)
        return outs

# %%
model = BiRNN(embed_size=100, num_hiddens=100, num_layers=5, classes=5)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
def batch_padding(batch_data):
    # 针对一批句子的长度（词向量个数）不一样时，全部补0到最大句子长度
    new_batch_data = []
    max_len = 0
    for s in batch_data:
        s = torch.tensor(s)
        new_batch_data.append(s)
        max_len = max(max_len,s.shape[0])
    for i in range(len(new_batch_data)):
        new_batch_data[i] = F.pad(new_batch_data[i], [0, 0, 0, max_len-new_batch_data[i].shape[0]])
    return torch.stack(new_batch_data, 0)

# %%
sentences = batch_padding(x_train[0:5])
sentences.shape # [batch_size,句子中词的个数,词向量维度]
# Out:
# torch.Size([5, 13, 100])

# %%
print(model(sentences.to(device))) # 输出为OneHot编码形式
# Out:
# tensor([[-0.5068, -0.1169, -0.1425,  0.0110,  0.0864],
#         [-0.5138, -0.1232, -0.1287,  0.0242,  0.0984],
#         [-0.5005, -0.1210, -0.1408,  0.0139,  0.0895],
#         [-0.5057, -0.1159, -0.1449,  0.0076,  0.0841],
#         [-0.5091, -0.1133, -0.1446,  0.0066,  0.0823]], device='cuda:0',
#        grad_fn=<AddmmBackward>)

# %% [markdown]
# ## 训练

# %%
def train(model,dataset_x,dataset_y,num_epochs,
batch_size,optimizer,loss,batch_loss_list,batch_acc_list):
    model.train()
    for epoch in range(num_epochs):
        print("epoch",epoch)
        train_l_sum, train_acc_sum, n = 0.0, 0.0, 0
        batch_num = len(dataset_x) // batch_size
        for i in range(batch_num):
            X = batch_padding(dataset_x[i*batch_size : (i+1)*batch_size]).to(device)
            y = torch.tensor(dataset_y[i*batch_size : (i+1)*batch_size]).to(device)
            y_hat = model(X)
            y = y.argmax(dim=1).long()
            loss_ = loss(y_hat, y)
            optimizer.zero_grad()
            loss_.backward()
            optimizer.step()

            batch_loss = loss_.cpu().item()
            batch_acc = (y_hat.argmax(dim=1) == y).sum().cpu().item()
            batch_loss_list.append(batch_loss/batch_size)
            batch_acc_list.append(batch_acc/batch_size)
            print(f"epoch:{epoch},batch loss:{batch_loss/batch_size},batch acc:{batch_acc/batch_size}")

# %%
lr = 0.001
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad,model.parameters()), lr=lr)
loss = nn.CrossEntropyLoss().to(device)

# %%
batch_loss_list = []
batch_acc_list = []

# %%
print("training... ")
train(model=model,dataset_x=x_train,dataset_y=y_train,
num_epochs=30,batch_size=256,optimizer=optimizer,loss=loss,
batch_loss_list=batch_loss_list,batch_acc_list=batch_acc_list)
# torch.save(model,"models/BiLSTM_v3.npy")
# Out:
# training...
# epoch 0
# epoch:0,batch loss:0.007307041436433792,batch acc:0.0
# epoch:0,batch loss:0.016047818586230278,batch acc:0.66796875
# epoch:0,batch loss:0.018217334523797035,batch acc:0.60546875
# epoch:0,batch loss:0.01028434932231903,batch acc:0.578125
# epoch:0,batch loss:0.010732591152191162,batch acc:0.17578125
# epoch:0,batch loss:0.01171071920543909,batch acc:0.109375
# epoch:0,batch loss:0.00803788285702467,batch acc:0.62890625
# epoch:0,batch loss:0.009024969302117825,batch acc:0.6328125
# epoch:0,batch loss:0.007954890839755535,batch acc:0.640625
# epoch:0,batch loss:0.006234456319361925,batch acc:0.6015625
# epoch:0,batch loss:0.005577941425144672,batch acc:0.14453125
# epoch:0,batch loss:0.007674228399991989,batch acc:0.16015625
# epoch:0,batch loss:0.004540206398814917,batch acc:0.5703125
# epoch:0,batch loss:0.004336605314165354,batch acc:0.64453125
# epoch:0,batch loss:0.0055921198800206184,batch acc:0.65234375
# epoch 1
# epoch:1,batch loss:0.005888670217245817,batch acc:0.6640625
# epoch:1,batch loss:0.005053011700510979,batch acc:0.6640625
# epoch:1,batch loss:0.005989300552755594,batch acc:0.609375
# epoch:1,batch loss:0.005199512001127005,batch acc:0.5078125
# epoch:1,batch loss:0.004925700835883617,batch acc:0.47265625
# epoch:1,batch loss:0.00486493855714798,batch acc:0.61328125
# epoch:1,batch loss:0.004488811362534761,batch acc:0.62890625
# epoch:1,batch loss:0.004304096102714539,batch acc:0.6328125
# epoch:1,batch loss:0.004274463281035423,batch acc:0.640625
# epoch:1,batch loss:0.004772848915308714,batch acc:0.6171875
# epoch:1,batch loss:0.004229008685797453,batch acc:0.65234375
# epoch:1,batch loss:0.0036929878406226635,batch acc:0.67578125
# epoch:1,batch loss:0.0045707649551332,batch acc:0.61328125
# epoch:1,batch loss:0.004160713870078325,batch acc:0.64453125
# epoch:1,batch loss:0.003973723389208317,batch acc:0.65234375
# epoch 2
# epoch:2,batch loss:0.003955277614295483,batch acc:0.6640625
# epoch:2,batch loss:0.003768230089917779,batch acc:0.66796875
# epoch:2,batch loss:0.004247076343744993,batch acc:0.60546875
# epoch:2,batch loss:0.0037631054874509573,batch acc:0.66796875
# epoch:2,batch loss:0.0038249141070991755,batch acc:0.6796875
# epoch:2,batch loss:0.003991483710706234,batch acc:0.62890625
# epoch:2,batch loss:0.0038477296475321054,batch acc:0.63671875
# epoch:2,batch loss:0.004046049900352955,batch acc:0.63671875
# epoch:2,batch loss:0.003722638823091984,batch acc:0.6640625
# epoch:2,batch loss:0.004200503695756197,batch acc:0.6015625
# epoch:2,batch loss:0.004207197111099958,batch acc:0.640625
# epoch:2,batch loss:0.003452361561357975,batch acc:0.6875
# epoch:2,batch loss:0.004037804435938597,batch acc:0.62890625
# epoch:2,batch loss:0.0037121681962162256,batch acc:0.65234375
# epoch:2,batch loss:0.003743872744962573,batch acc:0.64453125
# epoch 3
# epoch:3,batch loss:0.0035943002440035343,batch acc:0.671875
# epoch:3,batch loss:0.003476433688774705,batch acc:0.671875
# epoch:3,batch loss:0.004196010529994965,batch acc:0.62890625
# epoch:3,batch loss:0.003638356691226363,batch acc:0.66796875
# epoch:3,batch loss:0.0036422524135559797,batch acc:0.69140625
# epoch:3,batch loss:0.003820158075541258,batch acc:0.62890625
# epoch:3,batch loss:0.0036956879775971174,batch acc:0.64453125
# epoch:3,batch loss:0.0042522381991147995,batch acc:0.6328125
# epoch:3,batch loss:0.0038855820894241333,batch acc:0.65625
# epoch:3,batch loss:0.0040317438542842865,batch acc:0.625
# epoch:3,batch loss:0.003880404168739915,batch acc:0.66015625
# epoch:3,batch loss:0.0034249539021402597,batch acc:0.70703125
# epoch:3,batch loss:0.004073095973581076,batch acc:0.625
# epoch:3,batch loss:0.0037063981872051954,batch acc:0.671875
# epoch:3,batch loss:0.003717248560860753,batch acc:0.65625
# epoch 4
# epoch:4,batch loss:0.0035267360508441925,batch acc:0.68359375
# epoch:4,batch loss:0.0033741951920092106,batch acc:0.6796875
# epoch:4,batch loss:0.004140047822147608,batch acc:0.62890625
# epoch:4,batch loss:0.003722765017300844,batch acc:0.65625
# epoch:4,batch loss:0.0036121485754847527,batch acc:0.65234375
# epoch:4,batch loss:0.0037858239375054836,batch acc:0.64453125
# epoch:4,batch loss:0.00375267188064754,batch acc:0.65234375
# epoch:4,batch loss:0.004137435462325811,batch acc:0.62890625
# epoch:4,batch loss:0.0037333639338612556,batch acc:0.66015625
# epoch:4,batch loss:0.0039435941725969315,batch acc:0.62109375
# epoch:4,batch loss:0.004047540482133627,batch acc:0.65234375
# epoch:4,batch loss:0.0032885221298784018,batch acc:0.7109375
# epoch:4,batch loss:0.0040511335246264935,batch acc:0.63671875
# epoch:4,batch loss:0.0038166458252817392,batch acc:0.65625
# epoch:4,batch loss:0.003669540397822857,batch acc:0.66015625
# epoch 5
# epoch:5,batch loss:0.0034446907229721546,batch acc:0.6796875
# epoch:5,batch loss:0.003432151861488819,batch acc:0.6796875
# epoch:5,batch loss:0.004102750215679407,batch acc:0.6328125
# epoch:5,batch loss:0.003609056118875742,batch acc:0.6796875
# epoch:5,batch loss:0.00342777487821877,batch acc:0.69921875
# epoch:5,batch loss:0.003748103277757764,batch acc:0.63671875
# epoch:5,batch loss:0.0036373818293213844,batch acc:0.65234375
# epoch:5,batch loss:0.00413816561922431,batch acc:0.62890625
# epoch:5,batch loss:0.0035800880286842585,batch acc:0.66796875
# epoch:5,batch loss:0.003929014317691326,batch acc:0.625
# epoch:5,batch loss:0.004033377394080162,batch acc:0.6640625
# epoch:5,batch loss:0.003201813204213977,batch acc:0.734375
# epoch:5,batch loss:0.004061942454427481,batch acc:0.6328125
# epoch:5,batch loss:0.0036454549990594387,batch acc:0.68359375
# epoch:5,batch loss:0.003722397843375802,batch acc:0.66015625
# epoch 6
# epoch:6,batch loss:0.003424856811761856,batch acc:0.6953125
# epoch:6,batch loss:0.0033800164237618446,batch acc:0.6796875
# epoch:6,batch loss:0.004223809577524662,batch acc:0.625
# epoch:6,batch loss:0.0035996586084365845,batch acc:0.65234375
# epoch:6,batch loss:0.003588652703911066,batch acc:0.671875
# epoch:6,batch loss:0.003702905960381031,batch acc:0.640625
# epoch:6,batch loss:0.0036389376036822796,batch acc:0.6484375
# epoch:6,batch loss:0.00416586734354496,batch acc:0.62890625
# epoch:6,batch loss:0.0035658562555909157,batch acc:0.67578125
# epoch:6,batch loss:0.0038873739540576935,batch acc:0.6171875
# epoch:6,batch loss:0.004065067041665316,batch acc:0.65625
# epoch:6,batch loss:0.0031847418285906315,batch acc:0.7265625
# epoch:6,batch loss:0.004164516925811768,batch acc:0.6328125
# epoch:6,batch loss:0.0037042712792754173,batch acc:0.66796875
# epoch:6,batch loss:0.003726400202140212,batch acc:0.67578125
# epoch 7
# epoch:7,batch loss:0.0034477682784199715,batch acc:0.68359375
# epoch:7,batch loss:0.0034440134186297655,batch acc:0.68359375
# epoch:7,batch loss:0.004338977392762899,batch acc:0.625
# epoch:7,batch loss:0.00359042314812541,batch acc:0.64453125
# epoch:7,batch loss:0.003653724677860737,batch acc:0.640625
# epoch:7,batch loss:0.00370357115752995,batch acc:0.64453125
# epoch:7,batch loss:0.0036616288125514984,batch acc:0.65234375
# epoch:7,batch loss:0.004135364666581154,batch acc:0.6328125
# epoch:7,batch loss:0.003588790539652109,batch acc:0.66015625
# epoch:7,batch loss:0.003925938159227371,batch acc:0.61328125
# epoch:7,batch loss:0.004068188369274139,batch acc:0.65625
# epoch:7,batch loss:0.0032014527823776007,batch acc:0.72265625
# epoch:7,batch loss:0.004189794883131981,batch acc:0.62890625
# epoch:7,batch loss:0.0037499209865927696,batch acc:0.66796875
# epoch:7,batch loss:0.003733077785000205,batch acc:0.67578125
# epoch 8
# epoch:8,batch loss:0.0033870097249746323,batch acc:0.69140625
# epoch:8,batch loss:0.003480652580037713,batch acc:0.68359375
# epoch:8,batch loss:0.004331372212618589,batch acc:0.62890625
# epoch:8,batch loss:0.0036014860961586237,batch acc:0.64453125
# epoch:8,batch loss:0.003681969828903675,batch acc:0.61328125
# epoch:8,batch loss:0.0037562400102615356,batch acc:0.640625
# epoch:8,batch loss:0.003704755799844861,batch acc:0.65625
# epoch:8,batch loss:0.004054703749716282,batch acc:0.6328125
# epoch:8,batch loss:0.003618765389546752,batch acc:0.640625
# epoch:8,batch loss:0.003947108052670956,batch acc:0.6171875
# epoch:8,batch loss:0.00402503227815032,batch acc:0.6796875
# epoch:8,batch loss:0.0031903188209980726,batch acc:0.71875
# epoch:8,batch loss:0.00407063215970993,batch acc:0.640625
# epoch:8,batch loss:0.0037902165204286575,batch acc:0.66796875
# epoch:8,batch loss:0.0036915556993335485,batch acc:0.6796875
# epoch 9
# epoch:9,batch loss:0.0033746263943612576,batch acc:0.69140625
# epoch:9,batch loss:0.0034757801331579685,batch acc:0.6875
# epoch:9,batch loss:0.00432219821959734,batch acc:0.6328125
# epoch:9,batch loss:0.003657311899587512,batch acc:0.63671875
# epoch:9,batch loss:0.003643989097326994,batch acc:0.6328125
# epoch:9,batch loss:0.00385618070140481,batch acc:0.640625
# epoch:9,batch loss:0.0037233077455312014,batch acc:0.65625
# epoch:9,batch loss:0.004042215645313263,batch acc:0.6328125
# epoch:9,batch loss:0.0036526478361338377,batch acc:0.62890625
# epoch:9,batch loss:0.004060528706759214,batch acc:0.60546875
# epoch:9,batch loss:0.0040712314657866955,batch acc:0.67578125
# epoch:9,batch loss:0.0032076628413051367,batch acc:0.71484375
# epoch:9,batch loss:0.004049175884574652,batch acc:0.63671875
# epoch:9,batch loss:0.003882148303091526,batch acc:0.671875
# epoch:9,batch loss:0.0036392821930348873,batch acc:0.671875
# epoch 10
# epoch:10,batch loss:0.003413503523916006,batch acc:0.6953125
# epoch:10,batch loss:0.00346543500199914,batch acc:0.69140625
# epoch:10,batch loss:0.0042572710663080215,batch acc:0.63671875
# epoch:10,batch loss:0.0036674062721431255,batch acc:0.64453125
# epoch:10,batch loss:0.003494766540825367,batch acc:0.6796875
# epoch:10,batch loss:0.0039121233858168125,batch acc:0.6328125
# epoch:10,batch loss:0.0037197216879576445,batch acc:0.65625
# epoch:10,batch loss:0.003964941017329693,batch acc:0.6484375
# epoch:10,batch loss:0.003641796763986349,batch acc:0.62109375
# epoch:10,batch loss:0.004073691554367542,batch acc:0.62109375
# epoch:10,batch loss:0.0041031199507415295,batch acc:0.6796875
# epoch:10,batch loss:0.00319920782931149,batch acc:0.7265625
# epoch:10,batch loss:0.003970543388277292,batch acc:0.64453125
# epoch:10,batch loss:0.0038181946147233248,batch acc:0.68359375
# epoch:10,batch loss:0.0036361543461680412,batch acc:0.66796875
# epoch 11
# epoch:11,batch loss:0.0033787908032536507,batch acc:0.6953125
# epoch:11,batch loss:0.0034091940615326166,batch acc:0.69921875
# epoch:11,batch loss:0.004303551744669676,batch acc:0.63671875
# epoch:11,batch loss:0.0036366411950439215,batch acc:0.63671875
# epoch:11,batch loss:0.0034945611841976643,batch acc:0.6875
# epoch:11,batch loss:0.0038815608713775873,batch acc:0.64453125
# epoch:11,batch loss:0.003691580146551132,batch acc:0.65625
# epoch:11,batch loss:0.0039426707662642,batch acc:0.64453125
# epoch:11,batch loss:0.0035624627489596605,batch acc:0.640625
# epoch:11,batch loss:0.00407530227676034,batch acc:0.625
# epoch:11,batch loss:0.004152266774326563,batch acc:0.6796875
# epoch:11,batch loss:0.0031820915173739195,batch acc:0.73046875
# epoch:11,batch loss:0.003996910993009806,batch acc:0.640625
# epoch:11,batch loss:0.0038600945845246315,batch acc:0.67578125
# epoch:11,batch loss:0.0036559884902089834,batch acc:0.671875
# epoch 12
# epoch:12,batch loss:0.003405150258913636,batch acc:0.6875
# epoch:12,batch loss:0.0034482311457395554,batch acc:0.6953125
# epoch:12,batch loss:0.004381489474326372,batch acc:0.63671875
# epoch:12,batch loss:0.0036725972313433886,batch acc:0.640625
# epoch:12,batch loss:0.0035408262629061937,batch acc:0.6640625
# epoch:12,batch loss:0.003949048928916454,batch acc:0.6484375
# epoch:12,batch loss:0.00372843025252223,batch acc:0.65234375
# epoch:12,batch loss:0.00390978017821908,batch acc:0.65234375
# epoch:12,batch loss:0.0035917682107537985,batch acc:0.65625
# epoch:12,batch loss:0.0040895575657486916,batch acc:0.61328125
# epoch:12,batch loss:0.004274532198905945,batch acc:0.671875
# epoch:12,batch loss:0.0032130146864801645,batch acc:0.73046875
# epoch:12,batch loss:0.003964920993894339,batch acc:0.65234375
# epoch:12,batch loss:0.003828270360827446,batch acc:0.66015625
# epoch:12,batch loss:0.0036943096201866865,batch acc:0.6640625
# epoch 13
# epoch:13,batch loss:0.0033315010368824005,batch acc:0.69140625
# epoch:13,batch loss:0.0033482033759355545,batch acc:0.69140625
# epoch:13,batch loss:0.004523054696619511,batch acc:0.640625
# epoch:13,batch loss:0.0036465649027377367,batch acc:0.640625
# epoch:13,batch loss:0.0036177479196339846,batch acc:0.65625
# epoch:13,batch loss:0.003974182065576315,batch acc:0.63671875
# epoch:13,batch loss:0.003761250525712967,batch acc:0.65234375
# epoch:13,batch loss:0.004057155456393957,batch acc:0.6484375
# epoch:13,batch loss:0.0035579537507146597,batch acc:0.65234375
# epoch:13,batch loss:0.004105903208255768,batch acc:0.6171875
# epoch:13,batch loss:0.004417184740304947,batch acc:0.6640625
# epoch:13,batch loss:0.0032696262933313847,batch acc:0.7265625
# epoch:13,batch loss:0.004019088577479124,batch acc:0.63671875
# epoch:13,batch loss:0.003959172405302525,batch acc:0.6640625
# epoch:13,batch loss:0.0036535938270390034,batch acc:0.66015625
# epoch 14
# epoch:14,batch loss:0.0033793295733630657,batch acc:0.6953125
# epoch:14,batch loss:0.0034060755278915167,batch acc:0.6953125
# epoch:14,batch loss:0.004274067934602499,batch acc:0.63671875
# epoch:14,batch loss:0.00369151309132576,batch acc:0.62890625
# epoch:14,batch loss:0.003459096886217594,batch acc:0.68359375
# epoch:14,batch loss:0.003987327218055725,batch acc:0.6484375
# epoch:14,batch loss:0.0036818624939769506,batch acc:0.6484375
# epoch:14,batch loss:0.004082263447344303,batch acc:0.6484375
# epoch:14,batch loss:0.0034790572244673967,batch acc:0.671875
# epoch:14,batch loss:0.004119154065847397,batch acc:0.62109375
# epoch:14,batch loss:0.004296308849006891,batch acc:0.6875
# epoch:14,batch loss:0.0031040520407259464,batch acc:0.72265625
# epoch:14,batch loss:0.003984425216913223,batch acc:0.63671875
# epoch:14,batch loss:0.0038035486359149218,batch acc:0.67578125
# epoch:14,batch loss:0.0036529279313981533,batch acc:0.66796875
# epoch 15
# epoch:15,batch loss:0.0033069720957428217,batch acc:0.6796875
# epoch:15,batch loss:0.003351554973050952,batch acc:0.6953125
# epoch:15,batch loss:0.004356331191956997,batch acc:0.62890625
# epoch:15,batch loss:0.003574739210307598,batch acc:0.67578125
# epoch:15,batch loss:0.003526613349094987,batch acc:0.65234375
# epoch:15,batch loss:0.0039014997892081738,batch acc:0.63671875
# epoch:15,batch loss:0.003657899796962738,batch acc:0.66796875
# epoch:15,batch loss:0.0040106759406626225,batch acc:0.65234375
# epoch:15,batch loss:0.00348630640655756,batch acc:0.66796875
# epoch:15,batch loss:0.004078061785548925,batch acc:0.62109375
# epoch:15,batch loss:0.004410739056766033,batch acc:0.671875
# epoch:15,batch loss:0.00320097291842103,batch acc:0.734375
# epoch:15,batch loss:0.0040717045776546,batch acc:0.64453125
# epoch:15,batch loss:0.0036338407080620527,batch acc:0.6953125
# epoch:15,batch loss:0.0037756143137812614,batch acc:0.66796875
# epoch 16
# epoch:16,batch loss:0.0033767458517104387,batch acc:0.69921875
# epoch:16,batch loss:0.003290112130343914,batch acc:0.703125
# epoch:16,batch loss:0.004536343738436699,batch acc:0.64453125
# epoch:16,batch loss:0.0036280814092606306,batch acc:0.6484375
# epoch:16,batch loss:0.003646360244601965,batch acc:0.671875
# epoch:16,batch loss:0.004031825810670853,batch acc:0.64453125
# epoch:16,batch loss:0.003595396177843213,batch acc:0.65234375
# epoch:16,batch loss:0.004072416573762894,batch acc:0.640625
# epoch:16,batch loss:0.0035711147356778383,batch acc:0.6484375
# epoch:16,batch loss:0.004134720657020807,batch acc:0.61328125
# epoch:16,batch loss:0.004324488341808319,batch acc:0.6875
# epoch:16,batch loss:0.0032372809946537018,batch acc:0.734375
# epoch:16,batch loss:0.003990364260971546,batch acc:0.640625
# epoch:16,batch loss:0.0035516805946826935,batch acc:0.69140625
# epoch:16,batch loss:0.0037964016664773226,batch acc:0.6640625
# epoch 17
# epoch:17,batch loss:0.0033069320488721132,batch acc:0.6875
# epoch:17,batch loss:0.0032564285211265087,batch acc:0.6953125
# epoch:17,batch loss:0.004410767927765846,batch acc:0.640625
# epoch:17,batch loss:0.003585406579077244,batch acc:0.6484375
# epoch:17,batch loss:0.00361507385969162,batch acc:0.6796875
# epoch:17,batch loss:0.0040105911903083324,batch acc:0.640625
# epoch:17,batch loss:0.0035414511803537607,batch acc:0.65625
# epoch:17,batch loss:0.004022653680294752,batch acc:0.6484375
# epoch:17,batch loss:0.003522144164890051,batch acc:0.65234375
# epoch:17,batch loss:0.004122299142181873,batch acc:0.60546875
# epoch:17,batch loss:0.004245964344590902,batch acc:0.671875
# epoch:17,batch loss:0.0031562726944684982,batch acc:0.73828125
# epoch:17,batch loss:0.003920052200555801,batch acc:0.640625
# epoch:17,batch loss:0.003428675467148423,batch acc:0.69140625
# epoch:17,batch loss:0.003793388372287154,batch acc:0.6640625
# epoch 18
# epoch:18,batch loss:0.0032867512200027704,batch acc:0.68359375
# epoch:18,batch loss:0.00326119945384562,batch acc:0.71875
# epoch:18,batch loss:0.004469653591513634,batch acc:0.63671875
# epoch:18,batch loss:0.003534237388521433,batch acc:0.6796875
# epoch:18,batch loss:0.0037500017788261175,batch acc:0.6484375
# epoch:18,batch loss:0.0039810435846447945,batch acc:0.64453125
# epoch:18,batch loss:0.0036039804108440876,batch acc:0.66015625
# epoch:18,batch loss:0.00402497686445713,batch acc:0.65234375
# epoch:18,batch loss:0.003554845927283168,batch acc:0.6484375
# epoch:18,batch loss:0.004010987933725119,batch acc:0.62890625
# epoch:18,batch loss:0.004287275485694408,batch acc:0.6875
# epoch:18,batch loss:0.003104760777205229,batch acc:0.73046875
# epoch:18,batch loss:0.004003782290965319,batch acc:0.640625
# epoch:18,batch loss:0.003490098752081394,batch acc:0.6953125
# epoch:18,batch loss:0.0037949071265757084,batch acc:0.6640625
# epoch 19
# epoch:19,batch loss:0.0033420713152736425,batch acc:0.6875
# epoch:19,batch loss:0.0032640541903674603,batch acc:0.69921875
# epoch:19,batch loss:0.004436496179550886,batch acc:0.640625
# epoch:19,batch loss:0.003486342029646039,batch acc:0.6796875
# epoch:19,batch loss:0.0037218090146780014,batch acc:0.6484375
# epoch:19,batch loss:0.0039535751566290855,batch acc:0.640625
# epoch:19,batch loss:0.0036508666817098856,batch acc:0.65234375
# epoch:19,batch loss:0.004031136631965637,batch acc:0.6484375
# epoch:19,batch loss:0.0035899959038943052,batch acc:0.65625
# epoch:19,batch loss:0.0039841714315116405,batch acc:0.61328125
# epoch:19,batch loss:0.004257285501807928,batch acc:0.66796875
# epoch:19,batch loss:0.0031430975068360567,batch acc:0.7265625
# epoch:19,batch loss:0.0039807395078241825,batch acc:0.640625
# epoch:19,batch loss:0.0035284392070025206,batch acc:0.68359375
# epoch:19,batch loss:0.0037103479262441397,batch acc:0.66796875
# epoch 20
# epoch:20,batch loss:0.003319290466606617,batch acc:0.6875
# epoch:20,batch loss:0.003266454441472888,batch acc:0.72265625
# epoch:20,batch loss:0.004461120814085007,batch acc:0.63671875
# epoch:20,batch loss:0.0034586710389703512,batch acc:0.66015625
# epoch:20,batch loss:0.0037774010561406612,batch acc:0.64453125
# epoch:20,batch loss:0.0038749128580093384,batch acc:0.640625
# epoch:20,batch loss:0.0036235132720321417,batch acc:0.65625
# epoch:20,batch loss:0.0038617399986833334,batch acc:0.65625
# epoch:20,batch loss:0.0035753538832068443,batch acc:0.65625
# epoch:20,batch loss:0.004002440255135298,batch acc:0.6171875
# epoch:20,batch loss:0.004168432205915451,batch acc:0.6796875
# epoch:20,batch loss:0.0031028056982904673,batch acc:0.72265625
# epoch:20,batch loss:0.003861005650833249,batch acc:0.640625
# epoch:20,batch loss:0.003641570685431361,batch acc:0.69921875
# epoch:20,batch loss:0.003668517107143998,batch acc:0.671875
# epoch 21
# epoch:21,batch loss:0.0032730938401073217,batch acc:0.69921875
# epoch:21,batch loss:0.003270958084613085,batch acc:0.71484375
# epoch:21,batch loss:0.004271958488970995,batch acc:0.64453125
# epoch:21,batch loss:0.003383551724255085,batch acc:0.6875
# epoch:21,batch loss:0.0035983824636787176,batch acc:0.6484375
# epoch:21,batch loss:0.0038362406194210052,batch acc:0.64453125
# epoch:21,batch loss:0.003617403795942664,batch acc:0.671875
# epoch:21,batch loss:0.003937217406928539,batch acc:0.6484375
# epoch:21,batch loss:0.003515832591801882,batch acc:0.65625
# epoch:21,batch loss:0.003940023016184568,batch acc:0.6328125
# epoch:21,batch loss:0.004462380427867174,batch acc:0.51171875
# epoch:21,batch loss:0.003105615032836795,batch acc:0.73046875
# epoch:21,batch loss:0.004281064495444298,batch acc:0.6328125
# epoch:21,batch loss:0.0041369907557964325,batch acc:0.69140625
# epoch:21,batch loss:0.003925772849470377,batch acc:0.66015625
# epoch 22
# epoch:22,batch loss:0.0032737241126596928,batch acc:0.69140625
# epoch:22,batch loss:0.003412448801100254,batch acc:0.703125
# epoch:22,batch loss:0.00432670209556818,batch acc:0.6484375
# epoch:22,batch loss:0.003706536255776882,batch acc:0.65234375
# epoch:22,batch loss:0.0034727584570646286,batch acc:0.66015625
# epoch:22,batch loss:0.0038767834194004536,batch acc:0.6484375
# epoch:22,batch loss:0.0034926431253552437,batch acc:0.6484375
# epoch:22,batch loss:0.003900362178683281,batch acc:0.6484375
# epoch:22,batch loss:0.003537210635840893,batch acc:0.671875
# epoch:22,batch loss:0.003997275605797768,batch acc:0.6171875
# epoch:22,batch loss:0.004296229220926762,batch acc:0.6328125
# epoch:22,batch loss:0.0030071891378611326,batch acc:0.75
# epoch:22,batch loss:0.004027778748422861,batch acc:0.63671875
# epoch:22,batch loss:0.0036554131656885147,batch acc:0.69140625
# epoch:22,batch loss:0.0036022216081619263,batch acc:0.66796875
# epoch 23
# epoch:23,batch loss:0.003321337513625622,batch acc:0.6796875
# epoch:23,batch loss:0.0032358651515096426,batch acc:0.70703125
# epoch:23,batch loss:0.004530854057520628,batch acc:0.6328125
# epoch:23,batch loss:0.003551978850737214,batch acc:0.6796875
# epoch:23,batch loss:0.003756362944841385,batch acc:0.62109375
# epoch:23,batch loss:0.0038864831440150738,batch acc:0.6328125
# epoch:23,batch loss:0.0036461332347244024,batch acc:0.65234375
# epoch:23,batch loss:0.004049363080412149,batch acc:0.6328125
# epoch:23,batch loss:0.0035107077565044165,batch acc:0.6640625
# epoch:23,batch loss:0.004058202728629112,batch acc:0.6015625
# epoch:23,batch loss:0.0042088814079761505,batch acc:0.68359375
# epoch:23,batch loss:0.0030984007753431797,batch acc:0.7265625
# epoch:23,batch loss:0.0038727985229343176,batch acc:0.64453125
# epoch:23,batch loss:0.0035214934032410383,batch acc:0.71484375
# epoch:23,batch loss:0.003750875359401107,batch acc:0.65625
# epoch 24
# epoch:24,batch loss:0.0032504810951650143,batch acc:0.703125
# epoch:24,batch loss:0.0032700044102966785,batch acc:0.71484375
# epoch:24,batch loss:0.00445844791829586,batch acc:0.63671875
# epoch:24,batch loss:0.003554216120392084,batch acc:0.66796875
# epoch:24,batch loss:0.0035493625327944756,batch acc:0.65234375
# epoch:24,batch loss:0.003851726185530424,batch acc:0.6484375
# epoch:24,batch loss:0.003512650728225708,batch acc:0.65625
# epoch:24,batch loss:0.004020851105451584,batch acc:0.64453125
# epoch:24,batch loss:0.0034635879565030336,batch acc:0.671875
# epoch:24,batch loss:0.004042300395667553,batch acc:0.62890625
# epoch:24,batch loss:0.004269004333764315,batch acc:0.6640625
# epoch:24,batch loss:0.0030715775210410357,batch acc:0.71484375
# epoch:24,batch loss:0.004108555614948273,batch acc:0.6328125
# epoch:24,batch loss:0.0038072841707617044,batch acc:0.68359375
# epoch:24,batch loss:0.003729708958417177,batch acc:0.671875
# epoch 25
# epoch:25,batch loss:0.0032638933043926954,batch acc:0.6953125
# epoch:25,batch loss:0.0033800299279391766,batch acc:0.69140625
# epoch:25,batch loss:0.00437469407916069,batch acc:0.62890625
# epoch:25,batch loss:0.003618706716224551,batch acc:0.66796875
# epoch:25,batch loss:0.0034822532907128334,batch acc:0.67578125
# epoch:25,batch loss:0.004022222477942705,batch acc:0.64453125
# epoch:25,batch loss:0.003696535713970661,batch acc:0.671875
# epoch:25,batch loss:0.003983499016612768,batch acc:0.65234375
# epoch:25,batch loss:0.0034391614608466625,batch acc:0.6796875
# epoch:25,batch loss:0.00401886273175478,batch acc:0.6171875
# epoch:25,batch loss:0.00436409329995513,batch acc:0.671875
# epoch:25,batch loss:0.0030820644460618496,batch acc:0.72265625
# epoch:25,batch loss:0.003970305435359478,batch acc:0.6328125
# epoch:25,batch loss:0.003509857691824436,batch acc:0.69921875
# epoch:25,batch loss:0.00374431349337101,batch acc:0.68359375
# epoch 26
# epoch:26,batch loss:0.0032874213065952063,batch acc:0.69921875
# epoch:26,batch loss:0.0033111260272562504,batch acc:0.703125
# epoch:26,batch loss:0.004454225301742554,batch acc:0.6484375
# epoch:26,batch loss:0.0035147552844136953,batch acc:0.66015625
# epoch:26,batch loss:0.003657468594610691,batch acc:0.63671875
# epoch:26,batch loss:0.003973841667175293,batch acc:0.64453125
# epoch:26,batch loss:0.0035488931462168694,batch acc:0.65234375
# epoch:26,batch loss:0.00425139581784606,batch acc:0.62109375
# epoch:26,batch loss:0.0035231660585850477,batch acc:0.671875
# epoch:26,batch loss:0.004113601054996252,batch acc:0.6171875
# epoch:26,batch loss:0.0042424737475812435,batch acc:0.65625
# epoch:26,batch loss:0.003084725933149457,batch acc:0.73828125
# epoch:26,batch loss:0.0041632079519331455,batch acc:0.625
# epoch:26,batch loss:0.0034959609620273113,batch acc:0.69140625
# epoch:26,batch loss:0.0038063654210418463,batch acc:0.671875
# epoch 27
# epoch:27,batch loss:0.0034154898021370173,batch acc:0.6953125
# epoch:27,batch loss:0.003244854509830475,batch acc:0.70703125
# epoch:27,batch loss:0.004682209342718124,batch acc:0.6328125
# epoch:27,batch loss:0.0036357231438159943,batch acc:0.64453125
# epoch:27,batch loss:0.0037182485684752464,batch acc:0.59375
# epoch:27,batch loss:0.003902942407876253,batch acc:0.6484375
# epoch:27,batch loss:0.003418752457946539,batch acc:0.65625
# epoch:27,batch loss:0.004143782891333103,batch acc:0.62890625
# epoch:27,batch loss:0.003599564777687192,batch acc:0.65625
# epoch:27,batch loss:0.003989637829363346,batch acc:0.62890625
# epoch:27,batch loss:0.004265358205884695,batch acc:0.62890625
# epoch:27,batch loss:0.0029977960512042046,batch acc:0.7265625
# epoch:27,batch loss:0.003967814613133669,batch acc:0.6328125
# epoch:27,batch loss:0.00348050519824028,batch acc:0.69921875
# epoch:27,batch loss:0.0038098327349871397,batch acc:0.6640625
# epoch 28
# epoch:28,batch loss:0.0033723998349159956,batch acc:0.69140625
# epoch:28,batch loss:0.0033240073826164007,batch acc:0.703125
# epoch:28,batch loss:0.004396132659167051,batch acc:0.640625
# epoch:28,batch loss:0.0034629637375473976,batch acc:0.65625
# epoch:28,batch loss:0.0037118270993232727,batch acc:0.6171875
# epoch:28,batch loss:0.003942482639104128,batch acc:0.65625
# epoch:28,batch loss:0.0035940748639404774,batch acc:0.65234375
# epoch:28,batch loss:0.00395467272028327,batch acc:0.65625
# epoch:28,batch loss:0.00366682605817914,batch acc:0.66015625
# epoch:28,batch loss:0.003917592111974955,batch acc:0.62890625
# epoch:28,batch loss:0.0042197671718895435,batch acc:0.671875
# epoch:28,batch loss:0.002933298470452428,batch acc:0.74609375
# epoch:28,batch loss:0.0039084856398403645,batch acc:0.640625
# epoch:28,batch loss:0.0035351430997252464,batch acc:0.68359375
# epoch:28,batch loss:0.0036429897882044315,batch acc:0.68359375
# epoch 29
# epoch:29,batch loss:0.003424227936193347,batch acc:0.6953125
# epoch:29,batch loss:0.0032535905484110117,batch acc:0.7109375
# epoch:29,batch loss:0.0042554098181426525,batch acc:0.640625
# epoch:29,batch loss:0.003453404875472188,batch acc:0.65234375
# epoch:29,batch loss:0.0036097450647503138,batch acc:0.6328125
# epoch:29,batch loss:0.003960227593779564,batch acc:0.64453125
# epoch:29,batch loss:0.003450610674917698,batch acc:0.6640625
# epoch:29,batch loss:0.003907117992639542,batch acc:0.640625
# epoch:29,batch loss:0.0035864750389009714,batch acc:0.65625
# epoch:29,batch loss:0.0039992439560592175,batch acc:0.625
# epoch:29,batch loss:0.004083703737705946,batch acc:0.67578125
# epoch:29,batch loss:0.0029767570085823536,batch acc:0.73828125
# epoch:29,batch loss:0.003886550199240446,batch acc:0.62890625
# epoch:29,batch loss:0.003550188848748803,batch acc:0.6875
# epoch:29,batch loss:0.003748097689822316,batch acc:0.671875

# %%
plt.xlabel('Iterations')
plt.ylabel('train loss')
plt.plot(np.arange(len(batch_loss_list)), batch_loss_list)

# %%
plt.xlabel('Iterations')
plt.ylabel('train acc')
plt.plot(np.arange(len(batch_acc_list)), batch_acc_list)

# %% [markdown]
# ## 测试

# %%
def test(model,dataset_x,dataset_y,pred_list,real_list):
    model.eval()
    for i in range(len(dataset_x)):
        X = torch.tensor([dataset_x[i]]).to(device)
        y = torch.tensor([dataset_y[i]]).to(device)
        y_hat = model(X)
        pred_list.append(y_hat.argmax(dim=1).cpu().item())
        real_list.append(y.argmax(dim=1).cpu().item())

# %%
# model = torch.load("models/BiLSTM_v3.npy")
pred_list = []
real_list = []
print("testing... ")
test(model,x_test,y_test,pred_list,real_list)
# Out:
# testing...

# %%
print(metrics.classification_report(real_list,pred_list))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.15      0.24       626
#            1       0.13      0.89      0.23       125
#            2       0.00      0.00      0.00       184
#            3       0.24      0.15      0.18        67
#
#     accuracy                           0.21      1002
#    macro avg       0.27      0.30      0.16      1002
# weighted avg       0.47      0.21      0.19      1002

# %%
cm = metrics.confusion_matrix(real_list,pred_list)
plot_confusion_matrix(cm,range(5),normalize=True,title='test dataset confusion matrix')
# Out:
# 显示百分比：
# [[ 0.15  0.81  0.00  0.04]
#  [ 0.09  0.89  0.00  0.02]
#  [ 0.07  0.91  0.00  0.02]
#  [ 0.21  0.63  0.01  0.15]]
